# %% [markdown]
# # Scraping

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
chrome_path = r'/Users/hongfan/chromeDriver/chromedriver'

# %%
options = webdriver.ChromeOptions()
prefs = {'profile.default_content_settings.popups': 0, 'download.default_directory': '/Users/hongfan/user-generated-content-analytics'}
options.add_experimental_option('prefs', prefs)

# %%
driver = webdriver.Chrome(chrome_path, chrome_options=options)

# %%
url="https://forums.edmunds.com/discussion/18576/general/x/edmunds-members-cars-conversations/p"

# %%
#scraping pages from n to m
def scrape_pages(n,m):
    a=[]
    c=[]
    d=[]
    q=[]
    for i in range(n, m):
        driver.get(url+ str(i))
        author_list = driver.find_elements_by_class_name('Author')
        all_list = driver.find_elements_by_xpath("//div[@class='Message userContent']")
        post_list = driver.find_elements_by_xpath("//div[@class='Message userContent']/p[not(contains(@class, 'QuoteText'))]")
        date_list = driver.find_elements_by_xpath("//span[@class='MItem DateCreated']")
        for j in range(len(date_list)):
            date=date_list[j].text
            d.append(date)
            author= author_list[j].text
            a.append(author)
            #if you want to extract the quote from comment:
            try:
                quote=all_list[j].find_element_by_class_name('UserQuote') 
            except NoSuchElementException:
                quote='No Quote'
            q.append(quote)
            comment = post_list[j].text
            c.append(comment)
    return d,a,q,c

# %%
data=scrape_pages(1,3)

# %%
import pandas as pd
data=pd.DataFrame({'date':data[0],'author':data[1],'quote':data[2],'comment':data[3]})

# %%
data
# Out:
#          date       author                                              quote  \
# 0   June 2014    Kirstie_H                                           No Quote
# 1   June 2014   graphicguy                                           No Quote
# 2   June 2014         bwia                                           No Quote
# 3   June 2014   imidazol97  <selenium.webdriver.remote.webelement.WebEleme...
# 4   June 2014     stickguy                                           No Quote
# 5   June 2014         bwia  <selenium.webdriver.remote.webelement.WebEleme...
# 6   June 2014         bwia  <selenium.webdriver.remote.webelement.WebEleme...
# 7   June 2014    Kirstie_H  <selenium.webdriver.remote.webelement.WebEleme...
# 8   June 2014   cdnpinhead                                           No Quote
# 9   June 2014   graphicguy  <selenium.webdriver.remote.webelement.WebEleme...
# 10  June 2014        ab348  <selenium.webdriver.remote.webelement.WebEleme...
# 11  June 2014        ab348  <selenium.webdriver.remote.webelement.WebEleme...
# 12  June 2014       mako1a                                           No Quote
# 13  June 2014   laurasdada  <selenium.webdriver.remote.webelement.WebEleme...
# 14  June 2014     Michaell  <selenium.webdriver.remote.webelement.WebEleme...
# 15  June 2014        kyfdx                                           No Quote
# 16  June 2014     houdini1                                           No Quote
# 17  June 2014   imidazol97                                           No Quote
# 18  June 2014   graphicguy  <selenium.webdriver.remote.webelement.WebEleme...
# 19  June 2014       stever                                           No Quote
# 20  June 2014   laurasdada  <selenium.webdriver.remote.webelement.WebEleme...
# 21  June 2014   graphicguy                                           No Quote
# 22  June 2014    Kirstie_H  <selenium.webdriver.remote.webelement.WebEleme...
# 23  June 2014    driver100                                           No Quote
# 24  June 2014        kyfdx  <selenium.webdriver.remote.webelement.WebEleme...
# 25  June 2014   imidazol97                                           No Quote
# 26  June 2014     stickguy                                           No Quote
# 27  June 2014     stickguy                                           No Quote
# 28  June 2014   imidazol97  <selenium.webdriver.remote.webelement.WebEleme...
# 29  June 2014        ab348                                           No Quote
# ..        ...          ...                                                ...
# 31  June 2014      jsyodes                                           No Quote
# 32  June 2014       stever                                           No Quote
# 33  June 2014    abacomike                                           No Quote
# 34  June 2014     Michaell  <selenium.webdriver.remote.webelement.WebEleme...
# 35  June 2014         bwia                                           No Quote
# 36  June 2014     stickguy                                           No Quote
# 37  June 2014        kyfdx                                           No Quote
# 38  June 2014         bwia  <selenium.webdriver.remote.webelement.WebEleme...
# 39  June 2014   graphicguy                                           No Quote
# 40  June 2014        robr2  <selenium.webdriver.remote.webelement.WebEleme...
# 41  June 2014     stickguy                                           No Quote
# 42  June 2014    abacomike                                           No Quote
# 43  June 2014       justg0  <selenium.webdriver.remote.webelement.WebEleme...
# 44  June 2014   graphicguy  <selenium.webdriver.remote.webelement.WebEleme...
# 45  June 2014   laurasdada                                           No Quote
# 46  June 2014   graphicguy                                           No Quote
# 47  June 2014       stever  <selenium.webdriver.remote.webelement.WebEleme...
# 48  June 2014  sterlingdog                                           No Quote
# 49  June 2014   laurasdada  <selenium.webdriver.remote.webelement.WebEleme...
# 50  June 2014   imidazol97  <selenium.webdriver.remote.webelement.WebEleme...
# 51  June 2014    abacomike                                           No Quote
# 52  June 2014     stickguy                                           No Quote
# 53  June 2014     Michaell  <selenium.webdriver.remote.webelement.WebEleme...
# 54  June 2014     stickguy                                           No Quote
# 55  June 2014    driver100  <selenium.webdriver.remote.webelement.WebEleme...
# 56  June 2014    driver100  <selenium.webdriver.remote.webelement.WebEleme...
# 57  June 2014  oldfarmer50  <selenium.webdriver.remote.webelement.WebEleme...
# 58  June 2014        robr2  <selenium.webdriver.remote.webelement.WebEleme...
# 59  June 2014  oldfarmer50  <selenium.webdriver.remote.webelement.WebEleme...
# 60  June 2014  oldfarmer50                                           No Quote
#
#                                               comment
# 0   This is the all-new continuation of "Stories f...
# 1                     I'm 2nd post....yee haw!!!!!!!!
# 2                                   Do I get a badge?
# 3   Great, but will it be possible to refer to old...
# 4   And one more thing how do I find and add a dis...
# 5   If you have posted in that discussion, click o...
# 6   If you are looking for a brand or model or a k...
# 7   if you want to bookmark this one, there is a l...
# 8           Thanks @stickguy, it worked like a charm.
# 9   Thanks imidazol97. I will try that later but s...
# 10  Thanks for that. While this new board loads fa...
# 11  No, but it's almost like you're famous. Just t...
# 12  Re: the old discussion. I'm not sure what will...
# 13  Okay, here am I also. Now I need to add this t...
# 14                           Looks like I've done it.
# 15  Something tells me we won't get to 100K on thi...
# 16         WOW! I'm almost famous....... Thanks......
# 17  Wow, that's a throwback to the old, old, old b...
# 18                          The more things change...
# 19  Agreed. It is very dumb and complex at the sam...
# 20  We don't even have a page number yet. Talk abo...
# 21  Well, you may be almost famous. But are you a ...
# 22  Having been through the archives just a few mo...
# 23  IIRC, the limit then was pretty small (1000 po...
# 24  C'mon, people, I'm sure we can average more th...
# 25  Anyone have an actual story about buying or se...
# 26                                       Minnie Pearl
# 27  "I'm just so proud to be here" !! Probably not...
# 28  We were discussing what is the real invoice nu...
# 29                       LD....got the reference!!!!!
# ..                                                ...
# 31  Wait, this discussion is limited to buying and...
# 32  I made an offer on a house last night...er, on...
# 33  Have seen a dozen or so convertibles in the la...
# 34             Congrats on the (potential) new house!
# 35  Was it perhaps too hot to have the tops down o...
# 36              An exotic purchase may be coming soon
# 37  In an earlier post I mentioned that I was cons...
# 38  I went through the website and this white 1999...
# 39  Like *Driver100, I want to have my own wheels ...
# 40                                      Any thoughts?
# 41        Looks nice enough. And not all that pricey.
# 42       Nothing to buy that's already on the island?
# 43           Yes, but it would be twice as expensive.
# 44  Interesting to note, while we were in Bermuda ...
# 45  He said they don't have a personal income tax ...
# 46  It's more than that - it's a 150% tax and each...
# 47   Been there 3 times. You really don't need a car.
# 48                                                  >
# 49  The salesperson I dealt with at BMW said that ...
# 50  In order to sell the car at invoice, he wanted...
# 51  And also the GM wanted to make sure I name our...
# 52  We had no problem whatsoever getting around on...
# 53  I actually spoke to one of the residents who w...
# 54  Replying how I was shocked anyone would like t...
# 55  Moral of the story.....never assume paradise i...
# 56  GG: I, too, was quite enamored of Bermuda. Had...
# 57  I liked the odd (to me) assortment of small ca...
# 58  LD...saw the Peugot covertible. Also interesti...
# 59  Found out they had a shortage of teachers (whi...
# 60  We'll go back...probably sooner rather than la...
#
# [61 rows x 4 columns]

# %%
filename=driver.find_elements_by_tag_name('title')
file = open(filename,'w+')
