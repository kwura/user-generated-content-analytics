# %% [markdown]
# # BeautifulSoup Scraping

# %%
# import jtplot module in notebook
from jupyterthemes import jtplot

# choose which theme to inherit plotting style from
# onedork | grade3 | oceans16 | chesterish | monokai | solarizedl | solarizedd
jtplot.style(theme='onedork')

# %%
# import the libraries
import requests
import csv
from bs4 import BeautifulSoup
import re
from robobrowser import RoboBrowser
import pandas as pd

# %% [markdown]
# <h2>Structure</h2>
# <ul>
#     <li>We can't access product reviews unless we're logged in as a registered user. So we have to handle login.</li>
#     <li>We will be using the most reviewed products page</li>
#     <li>We will focus on "Foundation" products</li>
#     <li>There are 7 different "Foundation" subcategories with its own unique "CategoryID" in its url
#         <ol>
#             <li><strong>Powder</strong> - CategoryID: 503</li>
#             <li><strong>Primer/Corrector</strong> - CategoryID: 504</li>
#             <li><strong>Stick</strong> - CategoryID: 506</li>
#             <li><strong>Tinted Moisturizer</strong> - CategoryID: 505</li>
#             <li><strong>Liquid</strong> - CategoryID: 502</li>
#             <li><strong>Crème</strong> - CategoryID: 501</li>
#             <li><strong>BB Cream</strong> - CategoryID: 507</li>
#         </ol>
#     </li>
#     <li>For each subcategory there are products that each have
#         <ul>
#             <li><strong>Brand Name</strong> </li>
#             <li><strong>Product Name</strong> </li>
#             <li><strong>Category</strong> </li>
#             <li><strong>Average Rating</strong> </li>
#             <li><strong>Total Number of Reviews</strong> </li>
#             <li><strong>% That Would Buy Again</strong></li>
#         </ul>
#     </li>
#     <li>We will be scraping the first 5 pages of products for each subcategory, with the exception of "Stick" as "Stick" only has 2 pages of products, and so we will only scrape two pages of products for "Stick"</li>
#     <li>When we click on a product page there are reviews on the bottom. For each review we will scrape
#         <ul>
#             <li><strong>Rating</strong> - 1 to 5 lipsticks (aka stars)</li>
#             <li><strong>username</strong> </li>
#             <li><strong>date</strong> - date that the review was posted</li>
#             <li><strong>age</strong> - age range of the reviewer</li>
#             <li><strong>skin</strong> - skin information of the reviewer</li>
#             <li><strong>hair</strong> - hair information of the reviewer</li>
#             <li><strong>eyes</strong> - eye color of the reviewer</li>
#             <li><strong>review</strong> - the review itself</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# ### Login

# %%
# login_url
login_url = "https://www.makeupalley.com/account/login.asp"

# %%
# let's login
browser = RoboBrowser(history=True)
browser.open(login_url)
form = browser.get_form(action='/account/login.asp')

form["UserName"] = input("Enter Username: ")
form["Password"] = input("Enter Password: ")
browser.session.headers['Referer'] = login_url

browser.submit_form(form)
# print(str(browser.select))

print("Login Successful!")
# Out:
# c:\python\python37\lib\site-packages\robobrowser\browser.py:40: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 40 of the file c:\python\python37\lib\site-packages\robobrowser\browser.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   features=self.browser.parser,
# Enter Username: ugca
# Enter Password: barua123
# Login Successful!

# %% [markdown]
# ### Begin Scraper

# %%
# Store the different categories in a list
categories = [
    "Powder",
    "Primer/Corrector",
    "Stick",
    "Tinted Moisturizer",
    "Liquid",
    "Crème",
    "BB Cream"
]

# %%
# Create a dictionary to to match each Subcategory with its CategoryID
cat_id = dict()
cat_id["Powder"] = 503
cat_id["Primer/Corrector"] = 504
cat_id["Stick"] = 506
cat_id["Tinted Moisturizer"] = 505
cat_id["Liquid"] = 502
cat_id["Crème"] = 501
cat_id["BB Cream"] = 507

# %%
# store product info: brand_name, product_name, category, average_rating, total_reviews, buy_again_percentage%
product_info = []

# %%
# store output for each review: product_name, rating, username, date, age, skin, hair, eyes, review
reviews = []

# %%
# skeleton url
base_url = "https://www.makeupalley.com/product/browse.asp/page=/pagesize=15/CategoryId=/topten=reviewed/AgeRange=0/"
base = "https://www.makeupalley.com"

# iterate through each category of foundation
for cat in categories:
    # 2 pages of products for stick
    if(cat == "Stick"):
        for i in range(1,3):
            # adjust the urls
            product_url = base_url.replace("page=", "page=" + str(i))
            product_url = product_url.replace("CategoryId=", "CategoryId=" + str(cat_id[cat]))
            
            # collect the url with the requests library
            page = requests.get(product_url)
            print(product_url)
            
            # get the html of the page in string form
            page_html = page.text

            # create the BeautifulSoup object that takes in the html in str form and a html/xml parser of choice either html.parser or lxml
            soup = BeautifulSoup(page_html, 'html.parser')

            # Pull all text from the div class : search-results
            product_search_results = soup.find(class_ = "search-results")
            
            # Grab all the rows of products
            product_list = product_search_results.find_all("tr")
            
            # get the attributes
            for product in product_list:
                # store product data
                row_product_data = []
                
                # grab all column information
                columns = product.find_all("td")
                
                # store variable for the product link
                product_link = ""
                for col in range(len(columns)):
                    # first column is brand
                    if(col == 0):
                        row_product_data.append(columns[col].text)
                        #print(columns[col].text)
                    
                    # second column is the product
                    elif(col == 1):
                        product_name = columns[col].find_all("a", href = True)[1]
                        row_product_data.append(product_name.text)
                        product_link = base + product_name["href"]
                        #print(product_name.text)
                       # print(product_link)
                    
                    # third column is the category name
                    elif(col == 2):
                        the_cat = columns[col].text 
                        row_product_data.append(the_cat)
                       # print(the_cat)
                        
                    # fourth column is avg rating
                    elif(col == 3):
                        avg_rating = float(columns[col].text)
                        row_product_data.append(avg_rating)
                        #print(avg_rating)
                    
                    # fifth columns is number of reviews
                    elif(col == 4):
                        num_reviews = int(columns[col].text.replace(",", ""))
                        row_product_data.append(num_reviews)
                        #print(num_reviews)
                        
                    # sixth column is buy again percentage
                    elif(col == 5):
                        buy_again = float(columns[col].text.replace("%", "")) / 100.0
                        row_product_data.append(buy_again)
                        #print(buy_again)
                        
                # throw this row data into the product_info list
                if(len(row_product_data) != 0):
                    product_info.append(row_product_data)
                    
                    # lets go to the product link
                    #print("This the product link")
                    #print(product_link)
                    product_page = requests.get(product_link)
                    
                    # get the html of the page in string form
                    product_page_html = product_page.text
                    
                    # create the BeautifulSoup object that takes in the html in str form and a html/xml parser of choice either html.parser or lxml
                    soup2 = BeautifulSoup(product_page_html, 'html.parser')
                    
                    # first find the product_id 
                    product_id_search = soup2.find("div" , {"id":"ItemId"})
                    try:
                        product_id = product_id_search.text
                        print("product_id:", product_id, "Scraping")
                        # grab the last page of reviews which is the href of the second to last div of class = track_paging_
                        page_trackers = soup2.find_all(class_ = "track_Paging_", href = True)
                        last_page = page_trackers[-2]["href"]
                    except:
                        print("this shit failed")
                        continue
                         
                    # do something hacky/ string manipulations to extract last page number
                    last_page_number = last_page[:-1]
                    start_index = last_page_number.find("page=")
                    last_page_number = int(last_page_number[start_index + 5:])
                    
                    #print("last_page:", last_page)
                    #print("last page number:", last_page_number)
                    
                    # skeleton
                    base_product_url = "https://www.makeupalley.com/product/showreview.asp/ItemID=/page=/"
    
                    # go through all the pages to scrape reviews!
                    # last_page_number + 1
                    for i in range(1, last_page_number + 1):
                        # update the product url
                        new_product_url = base_product_url.replace("ItemID=","ItemID=" + product_id)
                        new_product_url = new_product_url.replace("page=", "page="+ str(i))
                        #print(new_product_url)
                        
                        # get the html of the page in string form
                        new_product_page = requests.get(new_product_url)
                        new_product_page_html = new_product_page.text
                        
                        # create a beautiful soup object
                        soup3 = BeautifulSoup(new_product_page_html, 'html.parser')
                        
                        comment_list = soup3.find(id = "reviews-wrapper")
                        
                        real_comment_list = comment_list.find_all(class_ = "comments")
                        
                        # iterate through each comment
                        for comment in real_comment_list:
                            # store row data
                            row = []
                            
                            # get the product type
                            row.append(cat)
                            
                            # get the productname
                            row.append(product_name.text)
                            
                            # get the ratings
                            rating = comment.find(class_ = "lipies")
                            score = rating.find("span")
                            row.append(score["class"][0][2])
                            
                            # get username
                            username = comment.find(class_ = "user-name")
                            row.append(username.text.replace("\t", ""))
                            
                            # get the date
                            date = comment.find(class_ = "date")
                            row.append(date.text)
                            
                            # get age, skin, hair, and eyes
                            traits = comment.find(class_ = "important")
                            clean_traits = traits.text.replace("Age:", "")
                            clean_traits = clean_traits.replace("Skin", "")
                            clean_traits = clean_traits.replace("Hair", "")
                            clean_traits = clean_traits.replace("Eyes", "")
                            clean_traits = clean_traits.split(":")
                            for k in range(len(clean_traits)):
                                row.append(clean_traits[k].strip())
                            
                            # get the review
                            review = comment.find(class_ = "break-word")
                            try:
                                row.append(review.text.replace("\t",""))
                            except:
                                try:
                                    review = comment.find(class_ = "1break-word")
                                    row.append(review.text.replace("\t", ""))
                                except:
                                    print("it didn't work")
                                    continue
                            
                            # throw the row of data into reviews
                            reviews.append(row)
                    print("product_id:", product_id, "Complete")
                    
    # 5 pages of products for the rest
    else:
        for i in range(1,6):
            # adjust the urls
            product_url = base_url.replace("page=", "page=" + str(i))
            product_url = product_url.replace("CategoryId=", "CategoryId=" + str(cat_id[cat]))
            
            # collect the url with the requests library
            page = requests.get(product_url)
            print(product_url)
            
            # get the html of the page in string form
            page_html = page.text

            # create the BeautifulSoup object that takes in the html in str form and a html/xml parser of choice either html.parser or lxml
            soup = BeautifulSoup(page_html, 'html.parser')

            # Pull all text from the div class : search-results
            product_search_results = soup.find(class_ = "search-results")
            
            # Grab all the rows of products
            product_list = product_search_results.find_all("tr")
            
            # get the attributes
            for product in product_list:
                # store product data
                row_product_data = []
                
                # grab all column information
                columns = product.find_all("td")
                
                # store variable for the product link
                product_link = ""
                for col in range(len(columns)):
                    # first column is brand
                    if(col == 0):
                        row_product_data.append(columns[col].text)
                        #print(columns[col].text)
                    
                    # second column is the product
                    elif(col == 1):
                        product_name = columns[col].find_all("a", href = True)[1]
                        row_product_data.append(product_name.text)
                        product_link = base + product_name["href"]
                        #print(product_name.text)
                       # print(product_link)
                    
                    # third column is the category name
                    elif(col == 2):
                        the_cat = columns[col].text 
                        row_product_data.append(the_cat)
                       # print(the_cat)
                        
                    # fourth column is avg rating
                    elif(col == 3):
                        avg_rating = float(columns[col].text)
                        row_product_data.append(avg_rating)
                        #print(avg_rating)
                    
                    # fifth columns is number of reviews
                    elif(col == 4):
                        num_reviews = int(columns[col].text.replace(",", ""))
                        row_product_data.append(num_reviews)
                        #print(num_reviews)
                        
                    # sixth column is buy again percentage
                    elif(col == 5):
                        buy_again = float(columns[col].text.replace("%", "")) / 100.0
                        row_product_data.append(buy_again)
                        #print(buy_again)
                        
                # throw this row data into the product_info list
                if(len(row_product_data) != 0):
                    product_info.append(row_product_data)
                    
                    # lets go to the product link
                    #print("This the product link")
                    #print(product_link)
                    product_page = requests.get(product_link)
                    
                    # get the html of the page in string form
                    product_page_html = product_page.text
                    
                    # create the BeautifulSoup object that takes in the html in str form and a html/xml parser of choice either html.parser or lxml
                    soup2 = BeautifulSoup(product_page_html, 'html.parser')
                    
                    # first find the product_id 
                    product_id_search = soup2.find("div" , {"id":"ItemId"})
                    try:
                        product_id = product_id_search.text
                        print("product_id:", product_id, "Scraping")
                        page_trackers = soup2.find_all(class_ = "track_Paging_", href = True)
                        last_page = page_trackers[-2]["href"]
                    except:
                        print("this shit failed")
                        continue
                    
                    # do something hacky/ string manipulations to extract last page number
                    last_page_number = last_page[:-1]
                    start_index = last_page_number.find("page=")
                    last_page_number = int(last_page_number[start_index + 5:])
                    
                    #print("last_page:", last_page)
                    #print("last page number:", last_page_number)
                    
                    # skeleton
                    base_product_url = "https://www.makeupalley.com/product/showreview.asp/ItemID=/page=/"
    
                    # go through all the pages to scrape reviews!
                    # last_page_number + 1
                    for i in range(1, last_page_number + 1):
                        # update the product url
                        new_product_url = base_product_url.replace("ItemID=","ItemID=" + product_id)
                        new_product_url = new_product_url.replace("page=", "page="+ str(i))
                        #print(new_product_url)
                        
                        # get the html of the page in string form
                        new_product_page = requests.get(new_product_url)
                        new_product_page_html = new_product_page.text
                        
                        # create a beautiful soup object
                        soup3 = BeautifulSoup(new_product_page_html, 'html.parser')
                        try:
                            comment_list = soup3.find(id = "reviews-wrapper")
                            real_comment_list = comment_list.find_all(class_ = "comments")
                        except:
                            print("Skipping a page this didn't work")
                            continue
                        
                        # iterate through each comment
                        for comment in real_comment_list:
                            # store row data
                            row = []
                            
                            # get the product type
                            row.append(cat)
                            
                            # get the productname
                            row.append(product_name.text)
                            
                            # get the ratings
                            rating = comment.find(class_ = "lipies")
                            score = rating.find("span")
                            row.append(score["class"][0][2])
                            
                            # get username
                            username = comment.find(class_ = "user-name")
                            row.append(username.text.replace("\t", ""))
                            
                            # get the date
                            date = comment.find(class_ = "date")
                            row.append(date.text)
                            
                            # get age, skin, hair, and eyes
                            traits = comment.find(class_ = "important")
                            clean_traits = traits.text.replace("Age:", "")
                            clean_traits = clean_traits.replace("Skin", "")
                            clean_traits = clean_traits.replace("Hair", "")
                            clean_traits = clean_traits.replace("Eyes", "")
                            clean_traits = clean_traits.split(":")
                            for k in range(len(clean_traits)):
                                row.append(clean_traits[k].strip())
                            
                            # get the review
                            review = comment.find(class_ = "break-word")
                            try:
                                row.append(review.text.replace("\t",""))
                            except:
                                try:
                                    review = comment.find(class_ = "1break-word")
                                    row.append(review.text.replace("\t", ""))
                                except:
                                    print("it didn't work")
                                    continue
                            
                            # throw the row of data into reviews
                            reviews.append(row)
                            
                    print("product_id:", product_id, "Complete")
# Out:
# https://www.makeupalley.com/product/browse.asp/page=1/pagesize=15/CategoryId=503/topten=reviewed/AgeRange=0/
# product_id: 9246 Scraping
# product_id: 9246 Complete
# product_id: 25754 Scraping
# product_id: 25754 Complete
# product_id: 15111 Scraping
# product_id: 15111 Complete
# product_id: 78607 Scraping
# product_id: 78607 Complete
# product_id: 74290 Scraping
# product_id: 74290 Complete
# product_id: 120907 Scraping
# product_id: 120907 Complete
# product_id: 13145 Scraping
# product_id: 13145 Complete
# product_id: 100359 Scraping
# product_id: 100359 Complete
# product_id: 89705 Scraping
# product_id: 89705 Complete
# product_id: 67857 Scraping
# product_id: 67857 Complete
# product_id: 102364 Scraping
# product_id: 102364 Complete
# product_id: 70540 Scraping
# product_id: 70540 Complete
# product_id: 11317 Scraping
# product_id: 11317 Complete
# product_id: 116379 Scraping
# product_id: 116379 Complete
# product_id: 921 Scraping
# product_id: 921 Complete
# https://www.makeupalley.com/product/browse.asp/page=2/pagesize=15/CategoryId=503/topten=reviewed/AgeRange=0/
# product_id: 79641 Scraping
# product_id: 79641 Complete
# product_id: 2970 Scraping
# product_id: 2970 Complete
# product_id: 512 Scraping
# product_id: 512 Complete
# product_id: 7276 Scraping
# product_id: 7276 Complete
# product_id: 68241 Scraping
# product_id: 68241 Complete
# product_id: 100905 Scraping
# product_id: 100905 Complete
# product_id: 88833 Scraping
# product_id: 88833 Complete
# product_id: 73012 Scraping
# product_id: 73012 Complete
# product_id: 14628 Scraping
# product_id: 14628 Complete
# product_id: 53022 Scraping
# product_id: 53022 Complete
# product_id: 6967 Scraping
# product_id: 6967 Complete
# product_id: 100494 Scraping
# product_id: 100494 Complete
# product_id: 1193 Scraping
# product_id: 1193 Complete
# product_id: 83371 Scraping
# product_id: 83371 Complete
# product_id: 26048 Scraping
# product_id: 26048 Complete
# https://www.makeupalley.com/product/browse.asp/page=3/pagesize=15/CategoryId=503/topten=reviewed/AgeRange=0/
# product_id: 17368 Scraping
# product_id: 17368 Complete
# product_id: 6666 Scraping
# product_id: 6666 Complete
# product_id: 2083 Scraping
# product_id: 2083 Complete
# product_id: 6911 Scraping
# product_id: 6911 Complete
# product_id: 90835 Scraping
# product_id: 90835 Complete
# product_id: 138487 Scraping
# product_id: 138487 Complete
# 473           AmorePacific  Color Control Cushion Compact Broad Spectrum S...
# 474             Supergoop!       Daily Correct CC Cream Broad Spectrum SPF 35
#
#          Type  Avg Rating  Number of Reviews  Percentage Would Buy Again
# 0      Powder         3.7               3938                        0.66
# 1      Powder         2.9               3074                        0.44
# 2      Powder         3.5               1152                        0.59
# 3      Powder         3.5               1092                        0.62
# 4      Powder         3.6                800                        0.65
# 5      Powder         3.4                762                        0.59
# 6      Powder         4.0                664                        0.72
# 7      Powder         3.2                639                        0.55
# 8      Powder         4.0                592                        0.71
# 9      Powder         3.8                550                        0.68
# 10     Powder         3.9                455                        0.71
# 11     Powder         4.0                451                        0.72
# 12     Powder         3.8                434                        0.68
# 13     Powder         3.7                422                        0.63
# 14     Powder         3.4                400                        0.60
# 15     Powder         3.8                397                        0.68
# 16     Powder         4.1                389                        0.77
# 17     Powder         3.7                375                        0.63
# 18     Powder         3.4                369                        0.55
# 19     Powder         3.0                350                        0.46
# 20     Powder         3.7                329                        0.66
# 21     Powder         3.8                313                        0.67
# 22     Powder         3.7                306                        0.62
# 23     Powder         3.5                293                        0.57
# 24     Powder         3.8                289                        0.63
# 25     Powder         4.0                282                        0.70
# 26     Powder         3.0                277                        0.48
# 27     Powder         3.8                273                        0.65
# 28     Powder         3.7                252                        0.64
# 29     Powder         3.5                240                        0.62
# ..        ...         ...                ...                         ...
# 445  BB Cream         4.2                 70                        0.78
# 446  BB Cream         3.8                 69                        0.63
# 447  BB Cream         3.3                 68                        0.51
# 448  BB Cream         3.8                 67                        0.71
# 449  BB Cream         2.7                 66                        0.37
# 450  BB Cream         3.4                 66                        0.54
# 451  BB Cream         2.8                 64                        0.43
# 452  BB Cream         3.5                 64                        0.56
# 453  BB Cream         2.2                 60                        0.23
# 454  BB Cream         3.8                 59                        0.61
# 455  BB Cream         3.6                 57                        0.52
# 456  BB Cream         3.6                 57                        0.56
# 457  BB Cream         3.7                 57                        0.66
# 458  BB Cream         3.7                 56                        0.55
# 459  BB Cream         3.8                 55                        0.65
# 460  BB Cream         3.7                 54                        0.64
# 461  BB Cream         3.6                 52                        0.57
# 462  BB Cream         2.7                 50                        0.38
# 463  BB Cream         3.3                 49                        0.53
# 464  BB Cream         3.4                 48                        0.56
# 465  BB Cream         4.3                 48                        0.72
# 466  BB Cream         3.0                 47                        0.51
# 467  BB Cream         3.4                 47                        0.46
# 468  BB Cream         2.9                 46                        0.45
# 469  BB Cream         3.8                 45                        0.75
# 470  BB Cream         4.2                 45                        0.75
# 471  BB Cream         3.7                 45                        0.73
# 472  BB Cream         4.2                 45                        0.75
# 473  BB Cream         3.6                 45                        0.46
# 474  BB Cream         4.1                 45                        0.71
#
# [475 rows x 6 columns]

# %%
reviews_df = pd.DataFrame(reviews, columns = ["Type", "Product", "Rating", "Username", "Date", "Age", "Skin", "Hair", "Eyes", "Review"])

# %%
reviews_df
# Out:
#             Type                                       Product Rating  \
# 0         Powder             Studio Fix Powder Plus Foundation      4
# 1         Powder             Studio Fix Powder Plus Foundation      5
# 132645          sparklemotion     on  12/20/2014 8:17:00 PM        44-55
# 132646        AnythingVanilla     on  12/20/2014 6:10:00 PM        36-43
# 132647              Ferrishyn    on  11/23/2014 11:17:00 PM        36-43
# 132648                Cindi33     on  11/22/2014 6:51:00 PM        44-55
# 132649          PianoGirl1985      on  9/21/2014 9:15:00 PM        25-29
# 132650                Callie3      on  9/6/2014 12:57:00 AM        25-29
# 132651             Jaded11885     on  8/20/2014 10:15:00 PM        25-29
# 132652               PISALISA     on  7/18/2014 11:25:00 AM        36-43
# 132653                alina08      on  7/13/2014 3:43:00 PM        25-29
# 132654         FunnyValentine       on  7/1/2014 1:13:00 AM        36-43
# 132655                 biocam      on  6/17/2014 5:07:00 AM        25-29
# 132656                 Paigey       on  6/6/2014 2:03:00 PM        30-35
# 132657          iamceliahodes       on  6/3/2014 9:44:00 PM        25-29
# 132658                  4eyes      on  5/18/2014 9:15:00 PM        44-55
# 132659           glitteratti1      on  5/15/2014 9:01:00 PM    56 & Over
# 132660            gommiebears       on  2/4/2014 4:06:00 PM        30-35
# 132661              shoedivas      on  1/16/2014 3:13:00 PM        44-55
# 132662              nanamisan     on  12/12/2013 5:50:00 PM        25-29
# 132663                blp1978      on  11/4/2013 2:52:00 PM        30-35
# 132664           VicklePickle      on  9/30/2013 3:06:00 PM        36-43
# 132665                 luxed2      on  9/21/2013 9:09:00 PM        44-55
# 132666               kanka999     on  8/23/2013 12:25:00 PM        36-43
# 132667          IslandGirlSPN      on  8/13/2013 2:52:00 PM        30-35
# 132668             ChynnaBlue     on  7/22/2013 11:54:00 AM        36-43
# 132669                  jinxd      on  6/17/2013 3:21:00 PM        30-35
# 132670               sheff803      on  5/24/2013 8:31:00 PM        19-24
# 132671              DeborahTX      on  5/18/2013 2:01:00 PM        36-43
#
#                                        Skin                        Hair  \
# 0               Oily, Fair-Medium, Not Sure         Brown, Other, Other
# 1                 Combination, Medium, Warm     Blond, Straight, Medium
# 2              Combination, Medium, Neutral     Other, Straight, Medium
# 3                 Very Oily, Dark, Not Sure         Blond, Other, Other
# 4                 Acne-prone, Fair, Neutral         Brown, Wavy, Coarse
# 5                    Dry, Fair-Medium, Cool       Silver, Other, Medium
# 6                    Dry, Fair-Medium, Cool           Black, Wavy, Fine
# 7                       Oily, Fair, Neutral         Blond, Wavy, Medium
# 8                       Dry, Fair, Not Sure      Brunette, Other, Other
# 9            Combination, Fair-Medium, Warm        Brown, Curly, Medium
# 10               Combination, Tan, Not Sure         Black, Other, Other
# 11               Acne-prone, Fair, Not Sure         Blond, Other, Other
# 12                   Normal, Fair, Not Sure      Brunette, Other, Other
# 13              Combination, Fair, Not Sure      Brunette, Other, Other
# 14                     Dry, Medium, Neutral      Brunette, Wavy, Medium
# 15               Combination, Tan, Not Sure         Black, Other, Other
# 16                   Dry, Fair-Medium, Warm    Brunette, Straight, Fine
# 17       Combination, Fair-Medium, Not Sure      Brunette, Other, Other
# 18       Combination, Fair-Medium, Not Sure         Black, Other, Other
# 19                      Dry, Fair, Not Sure      Brunette, Other, Other
# 20      Combination, Medium Brown, Not Sure         Brown, Other, Other
# 21                   Other, Other, Not Sure         Other, Other, Other
# 22               Very Dry, Medium, Not Sure         Black, Other, Other
# 23              Acne-prone, Other, Not Sure         Brown, Other, Other
# 24               Combination, Fair, Neutral        Blond, Relaxed, Fine
# 25                  Acne-prone, Olive, Warm       Black, Straight, Fine
# 26             Normal, Fair-Medium, Neutral      Brunette, Wavy, Medium
# 27                  Oily, Fair-Medium, Warm  Brunette, Straight, Medium
# 28                          Dry, Fair, Cool       Blond, Straight, Fine
# 29                   Other, Other, Not Sure         Other, Other, Other
# ...                                     ...                         ...
# 132642          Very Dry, Fair-Medium, Warm     Black, Straight, Medium
# 132643            Very Oily, Fair, Not Sure         Brown, Other, Other
# 132644           Acne-prone, Fair, Not Sure      Brunette, Other, Other
# 132645         Combination, Other, Not Sure      Brunette, Other, Other
# 132646                Normal, Fair, Neutral         Blond, Wavy, Medium
# 132647               Dry, Fair-Medium, Cool      Brunette, Wavy, Medium
# 132648                Normal, Fair, Neutral       Blond, Straight, Fine
# 132649       Combination, Fair-Medium, Warm    Brunette, Straight, Fine
# 132650          Combination, Fair, Not Sure         Blond, Wavy, Medium
# 132651           Dry, Fair-Medium, Not Sure      Brunette, Other, Other
# 132652    Combination, Fair-Medium, Neutral      Brunette, Wavy, Coarse
# 132653           Acne-prone, Fair, Not Sure       Blond, Straight, Fine
# 132654          Acne-prone, Other, Not Sure         Brown, Other, Other
# 132655   Combination, Fair-Medium, Not Sure      Brunette, Other, Other
# 132656   Combination, Fair-Medium, Not Sure        Brunette, Wavy, Fine
# 132657    Combination, Fair-Medium, Neutral         Other, Wavy, Medium
# 132658         Sensitive, Fair-Medium, Warm       Blond, Straight, Fine
# 132659           Dry, Fair-Medium, Not Sure         Blond, Other, Other
# 132660                Sensitive, Dark, Cool          Black, Kinky, Fine
# 132661           Combination, Tan, Not Sure        Brown, Curly, Coarse
# 132662    Acne-prone, Fair-Medium, Not Sure        Brunette, Wavy, Fine
# 132663                Oily, Olive, Not Sure      Brunette, Other, Other
# 132664   Combination, Fair-Medium, Not Sure           Blond, Wavy, Fine
# 132665      Sensitive, Fair-Medium, Neutral     Brown, Straight, Coarse
# 132666        Acne-prone, Fair-Medium, Warm      Brunette, Other, Other
# 132667               Dry, Fair-Medium, Cool  Brunette, Straight, Medium
# 132668          Combination, Fair, Not Sure          Red, Curly, Medium
# 132669             Sensitive, Fair, Neutral        Brunette, Wavy, Fine
# 132670            Sensitive, Fair, Not Sure         Blond, Other, Other
# 132671              Combination, Fair, Warm     Brunette, Relaxed, Fine
#
#           Eyes                                             Review
# 0        Brown  Nice pigmented powder, especially to cover ski...
# 1        Brown  This has become my go-to foundation now! My oi...
# 2        Green  This is an amazing powder foundation that leav...
# 3        Brown  Amazing powder that keeps you MATTE and keeps ...
# 4         Blue  I bought this powder a lot. I love it. It has ...
# 5        Hazel  I've been using MAC's Studio Fix Powder founda...
# 6        Black  i have dry skin and this makes my skin look wo...
# 7         Blue  TLDR; Great, buildable, flawless coverage but ...
# 8         Blue  I love all things MAC. Every product I've trie...
# 9        Brown  I hate that I love this foundation. I have NC2...
# 10       Brown  Never ever again. One of the worst Mac product...
# 11        Blue  Iâve tried quite possibly every top branded ...
# 12        Blue  This one is a must-have on my makeup kit. I do...
# 13       Hazel  I started using this with my Kat Von D foundat...
# 14       Brown  I color matched myself for this purchase since...
# 15       Brown  At last! One of the few MAC foundations I hadn...
# 16       Brown  This is the original OG of powder foundations....
# 17       Green  I cant say enough about this product. It is my...
# 18       Brown  There is a learning curve to using this, as is...
# 19       Green  i use this as a powder foundation with the opt...
# 20       Brown  My skin type: I really hate wearing and applyi...
# 21       Other  Dont buy this if you have the least dry skin. ...
# 22       Brown  I love Mac in general so I was pleased to find...
# 23       Brown        very cakey! makes pores and lines show bad!
# 24        Blue  Can use it as a powder foundation and setting ...
# 25       Brown  Overall: 4Price: 3 ($34 CAD)Packing: 4Buy agai...
# 26       Brown  I have been using this product since I first g...
# 27       Brown  This is the one when it comes to foundation fo...
# 28       Hazel  I have normal/dry skin and this powder in shad...
# 29       Other  I canât believe I avoided this for years due...
# ...        ...                                                ...
# 132642   Brown  This products evens out my skin tone very well...
# 132643    Blue  I use this as a primer. I have extremely oily ...
# 132644    Blue  I love this product!! I have been disappointed...
# 132645   Green  5 lippies but as a foundation it is not great....
# 132646   Hazel  Awesome stuff! I use this as my primer. It con...
# 132647   Hazel  This is a very nice CC cream and matched me pe...
# 132648    Blue  Love this product! I got this in my Birchbox a...
# 132649   Hazel  Wow! This is really, REALLY an excellent CC cr...
# 132650   Green  I received this CC cream in my Birchbox and I ...
# 132651    Blue  Ummm YES! I have dry acne prone skin and this ...
# 132652   Green  First, I have to say that this CC Cream is qui...
# 132653   Green  I got a sample of this through Birchbox and ha...
# 132654    Blue  This has an incredibly high amount of mineral ...
# 132655   Brown  I absolutely love this cc cream! It does not b...
# 132656    Blue  I heard about this via BB reviews, and bought ...
# 132657   Brown  I had previously used Dr. Jart+ ultimate BB cr...
# 132658   Hazel  I bought this before a truly awful IPL treatme...
# 132659   Hazel  Supergoop CC w/35SPF in Light/Medium has becom...
# 132660   Brown  A brief background on my skin: sensitive, acne...
# 132661   Brown  I had high hopes for this product because I lo...
# 132662   Brown  Even though i gave this three lippies, i reall...
# 132663  Violet  Okay so this is my first review ever for any m...
# 132664    Blue  This is the best tinted moisturizer/foundation...
# 132665   Brown  Like the previous reviewer, too dark and orang...
# 132666    Blue  I so wanted this to work because I really love...
# 132667   Brown  I had received a sample of this several months...
# 132668   Brown  I really like this CC cream, but the light sha...
# 132669   Hazel  Combo, ultra-sensitive, very acne-prone skin. ...
# 132670   Green  I was incredibly fortunate in receiving a samp...
# 132671   Brown  I received a sample of this in my BirchBox and...
#
# [132672 rows x 10 columns]

# %%
import numpy as np

# %%
reviews_df["Review"] = reviews_df['Review'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))

# %%
reviews_df.to_csv("reviews.csv")

# %%
products_df.to_csv("products.csv")
