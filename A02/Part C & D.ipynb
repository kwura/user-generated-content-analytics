# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# Perform lift and sentiment analysis on each candidate and issue:
# ![title](taskC.png)
#
# To do the above analysis, you will have to write a script to parse each tweet and extract parts that pertain to a candidate and attribute. Provide details of how you accomplished this task in a script.

# %%
# read the csv into a dataframe
tweets = pd.read_csv("tot_tweets.csv")
tweets = tweets.drop(columns=['id'])

# %%
tweets
# Out:
#                                 location  \
# 0                         Tennessee, USA
# 1                                    NaN
# 2                                    NaN
# 3                                America
# 4                             West Texas
# 5                             Dallas, TX
# 6                                    NaN
# 7                            Atlanta, GA
# 8                                 Oregon
# 9                              Australia
# 10                        PALM HARBOR FL
# 11                             Illinois
# 12                                   NaN
# 13                    San Antonio, Texas
# 14                         Austin, Texas
# 15                                   NaN
# 16              Toronto, Ontario, Canada
# 17                      Atlanta, Georgia
# 18                                   NaN
# 19                                 Texas
# 20                                Dallas
# 21                           Del Mar, CA
# 22                        Washington, DC
# 23                                   NaN
# 24    Deep in the 💙 of Texas 🇨🇱
# 25                                   NaN
# 26                              Mesa, AZ
# 27                                   NaN
# 28                                   NaN
# 29            Property of @HendriWigunah
# ...                                  ...
# 5711                                 NaN
# 5712                                 NaN
# 5713                          Newton, MA
# 5714                 North Carolina, USA
# 5715                                 NaN
# 5716                                 NaN
# 5717                       United States
# 5718                    Poughkeepsie, NY
# 5719             Toledo District, Belize
# 5720                     Saint Marys, GA
# 5721                          Texas, USA
# 5722               Riverside, California
# 5723                                 NaN
# 5724                                 NaN
# 5725                       United States
# 5726                          Dallas, TX
# 5727                               Texas
# 5728                        newport news
# 5729                          Resist, CA
# 5730                 South Carolina, USA
# 5731                       United States
# 5732         North Central, Philadelphia
# 5733                                 NaN
# 5734          Las Vegas, NV/ Lansing, MI
# 5735                            (ISFJ-A)
# 5736              Ozorków gmina, Polska
# 5737                          Poteau, OK
# 5738              Kansas, unfortunately
# 5739                                 NaN
# 5740                                 NaN
#
#                                                    text
# 0     b"RT @AliAdair22: \xf0\x9f\x90\xa6Next, Beto O...
# 1     b"RT @AliAdair22: \xf0\x9f\x90\xa6Next, Beto O...
# 2     b"Ted Cruz, Beto O'Rourke try to rally Latino ...
# 3     b'RT @RonNehring: Third poll now showing Cruz ...
# 4     b'Beto O\xe2\x80\x99Rourke, the Democratic con...
# 5     b'RT @wfaa: Does Texas\xe2\x80\x99 senate race...
# 6     b"RT @lizlogan76: Beto could win this, because...
# 7     b"RT @FoxNews: Ted Cruz, Beto O'Rourke try to ...
# 8     b"RT @Patriot_Musket: Lots of really good news...
# 9     b"RT @AMHotFlash: BETO'S campaign has raised m...
# 10    b"RT @JohnCornyn: Cruz vs. O'Rourke is most ex...
# 11    b'RT @MSNBC: "Ted Cruz has insisted that we re...
# 12    b"RT @FoxNews: Ted Cruz, Beto O'Rourke try to ...
# 13    b"Ted Cruz, Beto O'Rourke try to rally Latino ...
# 14    b'RT @MSNBC: "Ted Cruz has insisted that we re...
# 15    b'RT @UniteBlueTX: Ted Cruz declines, so chall...
# 16    b"RT @FoxNews: Ted Cruz, Beto O'Rourke try to ...
# 17    b"RT @JohnCornyn: Cruz vs. O'Rourke is most ex...
# 18    b'@SeanAstin what are your thoughts on Beto In...
# 19    b'.#BetoForSenate\n#BetoForTexas \n\xe2\x9a\xa...
# 20    b'Does Texas\xe2\x80\x99 senate race belong to...
# 21    b"RT @AMHotFlash: BETO'S campaign has raised m...
# 22    b"Does Texas' senate race belong to Texans? ht...
# 23    b'RT @dtxErgaOmnes: New poll has Beto O\xe2\x8...
# 24    b"RT @AMHotFlash: BETO'S campaign has raised m...
# 25    b'RT @BetoORourke: \xe2\x80\x9cI was initially...
# 26    b'More Voter purges in heavily contested Senat...
# 27    b"RT @FoxNews: Ted Cruz, Beto O'Rourke try to ...
# 28    b'RT @MSNBC: "Ted Cruz has insisted that we re...
# 29    b"Ted Cruz, Beto O'Rourke try to rally Latino ...
# ...                                                 ...
# 5711  b'RT @RJC: \xe2\x80\x9cI want to cut your taxe...
# 5712  b'RT @RJC: \xe2\x80\x9cI want to cut your taxe...
# 5713  b'RT @CBSNews: "Don\'t interrupt me, Jason," s...
# 5714  b'RT @OutFrontCNN: In Texas, can the Democrati...
# 5715  b'RT @CBSNews: "Don\'t interrupt me, Jason," s...
# 5716  b"RT @maccarty62: @GKeile @Childlikefaaith Yes...
# 5717  b'RT @TruthSoldierz: 20 DAYS TO VOTE!!\n  #ElP...
# 5718  b'RT @kwilli1046: Whom do you believe will win...
# 5719  b'RT @kwilli1046: Whom do you believe will win...
# 5720  b'RT @kwilli1046: Whom do you believe will win...
# 5721  b"RT @Hadleybeetee: @TeaPainUSA @BetoORourke L...
# 5722  b'RT @CBSNews: Cruz criticizes O\'Rourke for s...
# 5723  b'RT @kwilli1046: Whom do you believe will win...
# 5724  b'RT @kwilli1046: Whom do you believe will win...
# 5725  b'RT @kwilli1046: Whom do you believe will win...
# 5726  b"Battle of the rodents in Texas Senate race: ...
# 5727  b'I can name off towns and cities in Texas too...
# 5728  b'RT @Salon: Beto O\xe2\x80\x99Rourke dominate...
# 5729  b'RT @CBSNews: "Don\'t interrupt me, Jason," s...
# 5730  b'RT @kwilli1046: Whom do you believe will win...
# 5731  b'RT @kwilli1046: Whom do you believe will win...
# 5732  b'RT @matthewamiller: The Texas Senate race is...
# 5733  b'RT @NY2BOS73: Texas has a chance to do somet...
# 5734  b"O'Rourke attacks Cruz with 'Lyin' Ted' nickn...
# 5735  b'RT @CBSNews: "Don\'t interrupt me, Jason," s...
# 5736  b'RT @ABCPolitics: Rep. Beto O\'Rourke attacks...
# 5737  b'RT @kwilli1046: Whom do you believe will win...
# 5738  b"RT @jennycohn1: 11/ Looking ahead to @BetoOR...
# 5739  b'RT @kwilli1046: Whom do you believe will win...
# 5740  b'RT @kwilli1046: Whom do you believe will win...
#
# [5741 rows x 2 columns]

# %%
# Let's write a function to take care of the names
def replace_names(text):
    
    text = text.lower()
    
    beto_words = ['@betoorourke' , "beto o'rourke", "o'rourke", 'rourke']
    cruz_words = ['@tedcruz', 'ted cruz', 'ted']
    
    for w in beto_words:
        try:
            text = text.replace(w, 'beto')
        except:
            pass
    for w in cruz_words:
        try:
            text = text.replace(w, 'cruz')
        except:
            pass
    
    return text

# %%
# apply replace_names() on each tweet
text_column = []
for t in tweets.itertuples():
    text = t.text
    new_text = replace_names(text)
    text_column.append(new_text)

# %%
# replace old text with new text
tweets.text = text_column

# %%
for i in tweets.itertuples():
    text = i.text
    print(text)
    break
# Out:
# b"rt @aliadair22: \xf0\x9f\x90\xa6next, beto beto, running for u.s. senate in #texas. please follow, tweet, contribute, volunteer, anything\xe2\x80\xa6"

# %%
# word frequency
# grab word frequency using nltk library
import nltk
# stop words
from nltk.corpus import stopwords

# %%
# put all tweets together
text=tweets["text"].values.tolist()
text=" ".join(text)
text = text.lower()

# %%
# tokenize the text 
tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(text)

# %%
# let's do a word count
from collections import Counter

# counter object
words = Counter()

# update counter with new words
words.update(tokens)

# %%
# first order check
words.most_common()[:10]
# Out:
# [('xe2', 6577),
#  ('x80', 6452),
#  ('b', 5743),
#  ('rt', 4791),
#  ('the', 4411),
#  ('xa6', 3838),
#  ('texas', 3134),
#  ('in', 3112),
#  ('beto', 3107),
#  ('cruz', 3104)]

# %%
# store the stop words
stopwords = stopwords.words('english')[:]

# %%
# lets do this again: remove stop words, single letter variable names
filter_words = Counter(x for x in tokens if x not in stopwords and x.isdigit() == False and len(x) != 1 and x.isalpha() == True)

# %%
filter_words.most_common()[:1000]
# Out:
# [('rt', 4791),
#  ('texas', 3134),
#  ('beto', 3107),
#  ('cruz', 3104),
#  ('senate', 3003),
#  ('https', 2088),
#  ('co', 2007),
#  ('race', 1956),
#  ('vote', 877),
#  ('single', 785),
#  ('msnbc', 735),
#  ('word', 722),
#  ('win', 703),
#  ('every', 662),
#  ('care', 656),
#  ('repeal', 652),
#  ('act', 652),
#  ('pre', 652),
#  ('insiscruz', 651),
#  ('affordable', 651),
#  ('including', 651),
#  ('protections', 651),
#  ('existing', 650),
#  ('condi', 650),
#  ('debate', 502),
#  ('nplease', 491),
#  ('believe', 487),
#  ('retweet', 483),
#  ('sample', 483),
#  ('bigger', 479),
#  ('size', 478),
#  ('guy', 401),
#  ('leads', 352),
#  ('show', 345),
#  ('skateboard', 343),
#  ('still', 337),
#  ('side', 336),
#  ('election', 334),
#  ('polling', 331),
#  ('skates', 327),
#  ('across', 327),
#  ('stage', 327),
#  ('hoping', 327),
#  ('dont', 327),
#  ('history', 319),
#  ('texassenate', 301),
#  ('million', 289),
#  ('want', 256),
#  ('looking', 241),
#  ('cbsnews', 238),
#  ('ahead', 237),
#  ('problem', 237),
#  ('integrity', 235),
#  ('serious', 232),
#  ('becaus', 232),
#  ('campaign', 224),
#  ('poll', 222),
#  ('says', 215),
#  ('proud', 211),
#  ('quarter', 210),
#  ('follow', 204),
#  ('leader', 198),
#  ('raised', 193),
#  ('ask', 189),
#  ('question', 188),
#  ('tried', 187),
#  ('importance', 186),
#  ('interrupt', 185),
#  ('jason', 185),
#  ('moderator', 185),
#  ('remaining', 185),
#  ('fundraising', 183),
#  ('seat', 180),
#  ('make', 180),
#  ('friends', 177),
#  ('amazing', 172),
#  ('wi', 169),
#  ('dominates', 165),
#  ('taxes', 163),
#  ('winning', 162),
#  ('money', 159),
#  ('salon', 155),
#  ('record', 153),
#  ('republican', 152),
#  ('ncruz', 150),
#  ('us', 149),
#  ('amhotflash', 147),
#  ('voters', 146),
#  ('senator', 145),
#  ('vs', 144),
#  ('nwe', 144),
#  ('country', 138),
#  ('really', 137),
#  ('chance', 136),
#  ('rep', 130),
#  ('get', 129),
#  ('expensive', 128),
#  ('wants', 128),
#  ('raises', 128),
#  ('johncornyn', 124),
#  ('hey', 123),
#  ('points', 122),
#  ('democrat', 120),
#  ('could', 117),
#  ('yes', 115),
#  ('mr', 113),
#  ('try', 111),
#  ('latino', 111),
#  ('trump', 111),
#  ('rally', 110),
#  ('need', 106),
#  ('via', 104),
#  ('realdonaldtrump', 104),
#  ('democratic', 102),
#  ('nhttps', 99),
#  ('keep', 99),
#  ('would', 98),
#  ('congressman', 97),
#  ('going', 96),
#  ('texasdebate', 95),
#  ('attack', 94),
#  ('calling', 94),
#  ('worth', 94),
#  ('texans', 90),
#  ('polls', 89),
#  ('clear', 89),
#  ('delusional', 88),
#  ('candidate', 87),
#  ('reuters', 87),
#  ('cattharmony', 87),
#  ('eough', 87),
#  ('one', 85),
#  ('closing', 85),
#  ('xba', 85),
#  ('said', 83),
#  ('raise', 82),
#  ('triples', 81),
#  ('rjc', 81),
#  ('cut', 81),
#  ('remarks', 81),
#  ('races', 80),
#  ('think', 79),
#  ('midterm', 78),
#  ('records', 77),
#  ('betoobeto', 77),
#  ('buckle', 77),
#  ('kids', 77),
#  ('foxnews', 76),
#  ('gop', 76),
#  ('trailing', 74),
#  ('aggressive', 73),
#  ('clock', 73),
#  ('aca', 72),
#  ('alone', 71),
#  ('issue', 71),
#  ('valu', 70),
#  ('people', 70),
#  ('years', 69),
#  ('big', 69),
#  ('hollywood', 68),
#  ('like', 68),
#  ('amp', 68),
#  ('sen', 68),
#  ('ndemturds', 68),
#  ('counting', 68),
#  ('look', 67),
#  ('rival', 67),
#  ('went', 67),
#  ('gets', 65),
#  ('ronnehring', 64),
#  ('lead', 64),
#  ('media', 64),
#  ('third', 63),
#  ('tonight', 60),
#  ('world', 60),
#  ('maga', 60),
#  ('losing', 60),
#  ('good', 59),
#  ('great', 59),
#  ('past', 58),
#  ('profiles', 57),
#  ('wait', 57),
#  ('covering', 57),
#  ('american', 57),
#  ('essenviews', 57),
#  ('democracy', 57),
#  ('rule', 57),
#  ('new', 56),
#  ('nbeto', 56),
#  ('coverag', 56),
#  ('reaction', 56),
#  ('experiment', 56),
#  ('exception', 56),
#  ('sacre', 55),
#  ('chances', 54),
#  ('sencruzcruz', 54),
#  ('breaks', 54),
#  ('beating', 53),
#  ('come', 53),
#  ('quinnipiac', 52),
#  ('last', 52),
#  ('remote', 52),
#  ('quinnipiacpoll', 52),
#  ('point', 51),
#  ('time', 51),
#  ('slate', 51),
#  ('cementing', 51),
#  ('using', 51),
#  ('finds', 50),
#  ('starcruz', 50),
#  ('republicans', 49),
#  ('stalls', 49),
#  ('rather', 48),
#  ('votebetofortexas', 48),
#  ('president', 48),
#  ('probably', 48),
#  ('support', 48),
#  ('nnnnguy', 48),
#  ('charlesppierce', 48),
#  ('happens', 47),
#  ('cruzcrew', 47),
#  ('nationwide', 47),
#  ('governor', 47),
#  ('jmcfeels', 47),
#  ('net', 47),
#  ('nnow', 47),
#  ('talk', 46),
#  ('independent', 46),
#  ('earns', 46),
#  ('endorsement', 45),
#  ('safetypindaily', 44),
#  ('mess', 43),
#  ('lyin', 43),
#  ('tuesday', 43),
#  ('cwebbonline', 42),
#  ('fingertips', 42),
#  ('le', 42),
#  ('cnnpolitics', 42),
#  ('previous', 41),
#  ('year', 41),
#  ('wipes', 41),
#  ('floor', 41),
#  ('embattled', 41),
#  ('epic', 41),
#  ('please', 40),
#  ('shattering', 40),
#  ('needs', 40),
#  ('america', 39),
#  ('votes', 39),
#  ('elect', 39),
#  ('mean', 39),
#  ('partisan', 39),
#  ('stop', 38),
#  ('choice', 38),
#  ('democrats', 38),
#  ('cruzcruz', 38),
#  ('nasty', 38),
#  ('despite', 38),
#  ('two', 37),
#  ('state', 37),
#  ('txsen', 37),
#  ('endorse', 37),
#  ('circus', 37),
#  ('rawstory', 37),
#  ('looks', 36),
#  ('hear', 36),
#  ('cnn', 36),
#  ('toughastexas', 36),
#  ('interesting', 36),
#  ('supporting', 35),
#  ('trumptrain', 35),
#  ('walkawayfromdemocrats', 35),
#  ('candy', 35),
#  ('bordersecurity', 35),
#  ('lawenforcement', 35),
#  ('advocate', 35),
#  ('ouesvpzayf', 35),
#  ('today', 34),
#  ('political', 34),
#  ('called', 34),
#  ('kennedy', 34),
#  ('latest', 34),
#  ('ran', 34),
#  ('climate', 34),
#  ('abolish', 34),
#  ('watched', 34),
#  ('wish', 34),
#  ('final', 33),
#  ('tax', 33),
#  ('thisweekabc', 32),
#  ('go', 32),
#  ('facts', 32),
#  ('jfk', 32),
#  ('cuts', 32),
#  ('dodge', 32),
#  ('excus', 32),
#  ('seconds', 32),
#  ('battle', 32),
#  ('breaking', 31),
#  ('nickname', 31),
#  ('impeachment', 31),
#  ('exactly', 31),
#  ('key', 30),
#  ('thinks', 30),
#  ('old', 30),
#  ('criticizes', 30),
#  ('days', 30),
#  ('made', 29),
#  ('raising', 29),
#  ('paulmayatl', 29),
#  ('type', 29),
#  ('generational', 29),
#  ('disaster', 29),
#  ('brings', 29),
#  ('change', 29),
#  ('redo', 29),
#  ('realjameswoods', 29),
#  ('fun', 29),
#  ('running', 28),
#  ('edwardthardy', 28),
#  ('jokes', 28),
#  ('taken', 28),
#  ('weeks', 28),
#  ('de', 28),
#  ('blisstabitha', 28),
#  ('man', 28),
#  ('el', 27),
#  ('day', 27),
#  ('red', 27),
#  ('beat', 27),
#  ('stale', 27),
#  ('recent', 27),
#  ('reporcruz', 27),
#  ('fund', 27),
#  ('reached', 27),
#  ('tha', 27),
#  ('news', 26),
#  ('chappaquiddick', 26),
#  ('college', 26),
#  ('run', 26),
#  ('swinging', 26),
#  ('paso', 25),
#  ('let', 25),
#  ('obvious', 25),
#  ('heacruz', 25),
#  ('voter', 24),
#  ('important', 24),
#  ('call', 24),
#  ('joe', 24),
#  ('midterms', 24),
#  ('niro', 24),
#  ('reliable', 24),
#  ('candidates', 24),
#  ('fact', 24),
#  ('attacks', 24),
#  ('times', 23),
#  ('reminder', 23),
#  ('dems', 23),
#  ('presidenttrump', 23),
#  ('cocaine', 23),
#  ('snuffed', 23),
#  ('unitevotered', 23),
#  ('joanofamerica', 23),
#  ('extremely', 23),
#  ('qualified', 23),
#  ('supporti', 23),
#  ('watch', 23),
#  ('came', 23),
#  ('ny', 22),
#  ('house', 22),
#  ('bet', 22),
#  ('take', 22),
#  ('immigration', 22),
#  ('caucasoid', 22),
#  ('iberians', 22),
#  ('larping', 22),
#  ('amerindians', 22),
#  ('ambiguous', 22),
#  ('ethnic', 22),
#  ('boom', 22),
#  ('comi', 22),
#  ('honest', 22),
#  ('showing', 21),
#  ('citybureaucrat', 21),
#  ('meto', 21),
#  ('hard', 21),
#  ('first', 21),
#  ('abpumfmcjm', 21),
#  ('asserts', 21),
#  ('hardball', 21),
#  ('live', 20),
#  ('night', 20),
#  ('later', 20),
#  ('pres', 20),
#  ('embarks', 20),
#  ('swing', 20),
#  ('keeping', 20),
#  ('continuing', 20),
#  ('xdb', 20),
#  ('tweet', 19),
#  ('solid', 19),
#  ('follows', 19),
#  ('politics', 19),
#  ('voting', 19),
#  ('see', 19),
#  ('event', 19),
#  ('youtube', 19),
#  ('nickmadincea', 19),
#  ('thursday', 19),
#  ('thinkprogress', 19),
#  ('dallas', 18),
#  ('know', 18),
#  ('campaigns', 18),
#  ('states', 18),
#  ('tough', 18),
#  ('shortly', 18),
#  ('contribute', 17),
#  ('anything', 17),
#  ('even', 17),
#  ('everyone', 17),
#  ('holds', 17),
#  ('send', 17),
#  ('volunteer', 16),
#  ('betofortexas', 16),
#  ('say', 16),
#  ('dem', 16),
#  ('video', 16),
#  ('lose', 16),
#  ('second', 16),
#  ('promised', 16),
#  ('dude', 16),
#  ('likely', 16),
#  ('right', 16),
#  ('leading', 16),
#  ('lying', 16),
#  ('late', 16),
#  ('entering', 15),
#  ('white', 15),
#  ('better', 15),
#  ('txpolitics', 15),
#  ('morningjoe', 15),
#  ('incumbent', 14),
#  ('october', 14),
#  ('montana', 14),
#  ('robert', 14),
#  ('visicruz', 14),
#  ('move', 14),
#  ('corpus', 14),
#  ('christi', 14),
#  ('tennessee', 14),
#  ('deadlinewh', 14),
#  ('game', 14),
#  ('outfrontcnn', 14),
#  ('comes', 14),
#  ('xef', 13),
#  ('someone', 13),
#  ('coming', 13),
#  ('tx', 13),
#  ('hope', 13),
#  ('wins', 13),
#  ('asks', 13),
#  ('nvote', 13),
#  ('campuses', 13),
#  ('walk', 13),
#  ('shoes', 13),
#  ('energy', 13),
#  ('pas', 13),
#  ('thecut', 13),
#  ('abcpolitics', 13),
#  ('non', 13),
#  ('txgov', 13),
#  ('txpol', 13),
#  ('betonbeto', 13),
#  ('joetalkshow', 13),
#  ('hi', 13),
#  ('deep', 13),
#  ('lol', 12),
#  ('topics', 12),
#  ('dreamers', 12),
#  ('help', 12),
#  ('turnout', 12),
#  ('ntexas', 12),
#  ('disrespectful', 12),
#  ('drive', 12),
#  ('elections', 12),
#  ('mind', 12),
#  ('consider', 12),
#  ('also', 12),
#  ('mtp', 12),
#  ('nation', 12),
#  ('charge', 12),
#  ('markknoller', 12),
#  ('ar', 12),
#  ('nails', 12),
#  ('testy', 12),
#  ('challenger', 11),
#  ('lot', 11),
#  ('family', 11),
#  ('vicenews', 11),
#  ('away', 11),
#  ('donaldjtrumpjr', 11),
#  ('drtookanauer', 11),
#  ('ok', 11),
#  ('nfl', 11),
#  ('kneeling', 11),
#  ('fla', 11),
#  ('liberal', 11),
#  ('blue', 11),
#  ('things', 11),
#  ('fake', 11),
#  ('thanks', 11),
#  ('stars', 11),
#  ('bright', 11),
#  ('heart', 11),
#  ('nhoscruz', 11),
#  ('nice', 11),
#  ('gloves', 11),
#  ('making', 11),
#  ('dishonest', 11),
#  ('frankluntz', 10),
#  ('focus', 10),
#  ('group', 10),
#  ('shows', 10),
#  ('bubble', 10),
#  ('anyone', 10),
#  ('iii', 10),
#  ('jaketapper', 10),
#  ('way', 10),
#  ('michaelavenatti', 10),
#  ('close', 10),
#  ('votebeto', 10),
#  ('potus', 10),
#  ('less', 10),
#  ('keeptexasred', 10),
#  ('sure', 10),
#  ('sense', 10),
#  ('texastribune', 10),
#  ('senat', 10),
#  ('collegedems', 10),
#  ('stanc', 10),
#  ('unicruz', 10),
#  ('stands', 10),
#  ('xda', 10),
#  ('betoforsenate', 9),
#  ('results', 9),
#  ('early', 9),
#  ('watching', 9),
#  ('draw', 9),
#  ('full', 9),
#  ('true', 9),
#  ('born', 9),
#  ('canada', 9),
#  ('trying', 9),
#  ('presidential', 9),
#  ('took', 9),
#  ('give', 9),
#  ('xbc', 9),
#  ('job', 9),
#  ('article', 9),
#  ('may', 9),
#  ('mailonline', 9),
#  ('ni', 9),
#  ('hispanic', 9),
#  ('lags', 9),
#  ('next', 9),
#  ('name', 9),
#  ('never', 9),
#  ('ad', 9),
#  ('nquote', 9),
#  ('voteredtosaveamerica', 9),
#  ('future', 9),
#  ('deciding', 9),
#  ('ca', 9),
#  ('three', 9),
#  ('sent', 8),
#  ('ties', 8),
#  ('wealthy', 8),
#  ('scrutiny', 8),
#  ('ads', 8),
#  ('wall', 8),
#  ('thehill', 8),
#  ('smart', 8),
#  ('month', 8),
#  ('tight', 8),
#  ('ev', 8),
#  ('inc', 8),
#  ('inside', 8),
#  ('knew', 8),
#  ('party', 8),
#  ('calls', 8),
#  ('seen', 8),
#  ('behind', 8),
#  ('happy', 8),
#  ('many', 8),
#  ('rakes', 8),
#  ('stretch', 8),
#  ('conservative', 8),
#  ('turn', 8),
#  ('love', 8),
#  ('real', 8),
#  ('science', 8),
#  ('human', 8),
#  ('death', 8),
#  ('endorses', 8),
#  ('half', 8),
#  ('na', 8),
#  ('missed', 8),
#  ('profjkaiyer', 8),
#  ('table', 8),
#  ('basically', 8),
#  ('takeaways', 8),
#  ('michaelskolnik', 8),
#  ('cor', 8),
#  ('historically', 8),
#  ('lowest', 8),
#  ('changes', 8),
#  ('hundreds', 8),
#  ('personal', 8),
#  ('commissioner', 8),
#  ('belong', 7),
#  ('weekend', 7),
#  ('nand', 7),
#  ('national', 7),
#  ('business', 7),
#  ('heard', 7),
#  ('actually', 7),
#  ('maybe', 7),
#  ('include', 7),
#  ('matter', 7),
#  ('taking', 7),
#  ('makes', 7),
#  ('florida', 7),
#  ('bobdrummond', 7),
#  ('cfgaction', 7),
#  ('wpaintel', 7),
#  ('nballot', 7),
#  ('comparison', 7),
#  ('millions', 7),
#  ('hate', 7),
#  ('francis', 7),
#  ('loses', 7),
#  ('haul', 7),
#  ('enters', 7),
#  ('low', 7),
#  ('wrong', 7),
#  ('spent', 7),
#  ('arizona', 7),
#  ('shot', 7),
#  ('talks', 7),
#  ('representative', 7),
#  ('face', 7),
#  ('put', 7),
#  ('talking', 7),
#  ('lauralitvan', 7),
#  ('marsha', 7),
#  ('blackburn', 7),
#  ('michael', 7),
#  ('pts', 7),
#  ('authenticity', 7),
#  ('got', 7),
#  ('houston', 7),
#  ('eleccruz', 7),
#  ('town', 7),
#  ('socialist', 7),
#  ('esquire', 7),
#  ('wcpy', 7),
#  ('electoral', 7),
#  ('message', 7),
#  ('allcharisma', 7),
#  ('yikes', 7),
#  ('cand', 7),
#  ('land', 7),
#  ('education', 7),
#  ('tale', 7),
#  ('rallies', 7),
#  ('daughter', 7),
#  ('goes', 7),
#  ('liked', 7),
#  ('trumpology', 7),
#  ('repbetoobeto', 7),
#  ('thousa', 7),
#  ('st', 7),
#  ('ringer', 7),
#  ('lots', 6),
#  ('cook', 6),
#  ('tv', 6),
#  ('la', 6),
#  ('etc', 6),
#  ('choosecruz', 6),
#  ('much', 6),
#  ('defeat', 6),
#  ('texan', 6),
#  ('txlege', 6),
#  ('soros', 6),
#  ('beta', 6),
#  ('nytimes', 6),
#  ('well', 6),
#  ('amervoices', 6),
#  ('asked', 6),
#  ('crazy', 6),
#  ('car', 6),
#  ('saw', 6),
#  ('hopeful', 6),
#  ('july', 6),
#  ('september', 6),
#  ('thedemcoalition', 6),
#  ('joseph', 6),
#  ('gap', 6),
#  ('several', 6),
#  ('months', 6),
#  ('wife', 6),
#  ('accomplished', 6),
#  ('represent', 6),
#  ('hell', 6),
#  ('cherijacobus', 6),
#  ('must', 6),
#  ('coverage', 6),
#  ('thing', 6),
#  ('danpatrick', 6),
#  ('large', 6),
#  ('attacked', 6),
#  ('paris', 6),
#  ('accord', 6),
#  ('millennial', 6),
#  ('cringed', 6),
#  ('buy', 6),
#  ('november', 6),
#  ('betomania', 6),
#  ('mikey', 6),
#  ('kiss', 6),
#  ('issues', 6),
#  ('ncreepy', 6),
#  ('porn', 6),
#  ('lawyer', 6),
#  ('avenatti', 6),
#  ('ncongratulations', 6),
#  ('hall', 6),
#  ('joke', 6),
#  ('peter', 6),
#  ('brown', 6),
#  ('discuss', 6),
#  ('texasgovernor', 6),
#  ('plummecruz', 6),
#  ('six', 6),
#  ('map', 6),
#  ('generation', 6),
#  ('expert', 6),
#  ('trad', 6),
#  ('rodents', 6),
#  ('blind', 6),
#  ('squirrel', 6),
#  ('missing', 6),
#  ('poor', 6),
#  ('trumpchatting', 6),
#  ('notocruzcruz', 6),
#  ('square', 6),
#  ('headlines', 6),
#  ('stil', 5),
#  ('declines', 5),
#  ('hour', 5),
#  ('th', 5),
#  ('happened', 5),
#  ('boy', 5),
#  ('thought', 5),
#  ('opponent', 5),
#  ('men', 5),
#  ('sets', 5),
#  ('story', 5),
#  ('press', 5),
#  ('posting', 5),
#  ('wheel', 5),
#  ('seems', 5),
#  ('fight', 5),
#  ('betor', 5),
#  ('dallasnews', 5),
#  ('tomhfh', 5),
#  ('term', 5),
#  ('donald', 5),
#  ('nnothing', 5),
#  ('gerrymandering', 5),
#  ('voteforbeto', 5),
#  ('signs', 5),
#  ('university', 5),
#  ('bluewave', 5),
#  ('among', 5),
#  ('stand', 5),
#  ('abc', 5),
#  ('anti', 5),
#  ('giving', 5),
#  ('insercruz', 5),
#  ('contentious', 5),
#  ('takes', 5),
#  ('though', 5),
#  ('network', 5),
#  ('larger', 5),
#  ('irish', 5),
#  ('speaks', 5),
#  ('im', 5),
#  ('sign', 5),
#  ('opening', 5),
#  ('nine', 5),
#  ('cannot', 5),
#  ('san', 5),
#  ('antonio', 5),
#  ('cruztovictory', 5),
#  ('common', 5),
#  ('rich', 5),
#  ('todosono', 5),
#  ('harder', 5),
#  ('mediajuggernaut', 5),
#  ('austin', 5),
#  ('que', 5),
#  ('trust', 5),
#  ('line', 5),
#  ('stevekling', 5),
#  ('wasting', 5),
#  ('registration', 5),
#  ('newshour', 5),
#  ('reuterspolitics', 5),
#  ('sends', 5),
#  ('quite', 5),
#  ('possibly', 5),
#  ('spar', 5),
#  ('hamster', 5),
#  ('investments', 5),
#  ('exploiting', 5),
#  ('omefwunxnz', 5),
#  ('votebetofort', 5),
#  ('jilevin', 5),
#  ('matthewamiller', 5),
#  ('normal', 5),
#  ('andro', 5),
#  ('nothing', 5),
#  ('runswitchpr', 5),
#  ('debt', 5),
#  ('xaf', 5),
#  ('wfaa', 4),
#  ('gxnrzdjhid', 4),
#  ('resist', 4),
#  ('journal', 4),
#  ('dtxergaomnes', 4),
#  ('nif', 4),
#  ('asking', 4),
#  ('donations', 4),
#  ('imagine', 4),
#  ('oklahoma', 4),
#  ('caring', 4),
#  ('inst', 4),
#  ('border', 4),
#  ('bad', 4),
#  ('since', 4),
#  ('discussing', 4),
#  ('explains', 4),
#  ('explain', 4),
#  ('gotten', 4),
#  ('fewer', 4),
#  ('five', 4),
#  ('remember', 4),
#  ('primary', 4),
#  ('cru', 4),
#  ('ntennessee', 4),
#  ('paul', 4),
#  ('dailymail', 4),
#  ('htt', 4),
#  ('period', 4),
#  ('missouri', 4),
#  ('gonna', 4),
#  ('back', 4),
#  ('wonder', 4),
#  ('seats', 4),
#  ('currently', 4),
#  ('getting', 4),
#  ('ever', 4),
#  ('nthe', 4),
#  ('done', 4),
#  ('hold', 4),
#  ('cr', 4),
#  ('annatinsley', 4),
#  ('guide', 4),
#  ('momentum', 4),
#  ('puts', 4),
#  ('double', 4),
#  ('hillary', 4),
#  ('use', 4),
#  ('meant', 4),
#  ('woman', 4),
#  ('yeah', 4),
#  ('bostonglobe', 4),
#  ('fo', 4),
#  ('recognition', 4),
#  ('midtermelections', 4),
#  ('pushing', 4),
#  ('always', 4),
#  ('spanish', 4),
#  ('worried', 4),
#  ('leaders', 4),
#  ('auburngirlx', 4),
#  ('something', 4),
#  ('usrealitycheck', 4),
#  ('deniers', 4),
#  ('data', 4),
#  ('changing', 4),
#  ('favorite', 4),
#  ('blood', 4),
#  ('fireworks', 4),
#  ('around', 4),
#  ('part', 4),
#  ('listen', 4),
#  ('opportunity', 4),
#  ('alliance', 4),
#  ('truth', 4),
#  ('giltpolitics', 4),
#  ('mi', 4),
#  ('questioning', 4),
#  ('slogan', 4),
#  ('liberals', 4),
#  ('giddy', 4),
#  ('thi', 4),
#  ('without', 4),
#  ('legislation', 4),
#  ('obama', 4),
#  ('authentically', 4),
#  ('cool', 4),
#  ('gave', 4),
#  ('et', 4),
#  ('reflects', 4),
#  ('demographic', 4),
#  ('divide', 4),
#  ('repeat', 4),
#  ('instead', 4),
#  ('worked', 4),
#  ('healthcare', 4),
#  ('leadership', 4),
#  ('whe', 4),
#  ('week', 4),
#  ('nevada', 4),
#  ('spike', 4),
#  ('certainly', 4),
#  ('zerlinamaxwell', 4),
#  ('bill', 4),
#  ('gt', 4),
#  ('nthis', 4),
#  ('honor', 4),
#  ('borrows', 4),
#  ('short', 4),
#  ('hammered', 4),
#  ('absolutely', 4),
#  ('tweets', 4),
#  ('mocking', 4),
#  ('arizonans', 4),
#  ('abcworldnews', 4),
#  ('demo', 4),
#  ('thirdbennn', 4),
#  ('mrmiguelsuazo', 4),
#  ('romanmcallen', 4),
#  ('railroad', 4),
#  ('qhtvlssryv', 4),
#  ('thoughts', 3),
#  ('york', 3),
#  ('strategy', 3),
#  ('hearing', 3),
#  ('pacs', 3),
#  ('breakdown', 3),
#  ('according', 3),
#  ('houstonchron', 3),
#  ('kick', 3),
#  ('nbig', 3),
#  ('text', 3),
#  ('decide', 3),
#  ('amarporashona', 3),
#  ('position', 3),
#  ('challenge', 3),
#  ('worl', 3),
#  ('dmn', 3),
#  ('crew', 3),
#  ('towards', 3),
#  ('laugh', 3),
#  ('differentiacruz', 3),
#  ('campa', 3),
#  ('oh', 3),
#  ('easily', 3),
#  ('spending', 3),
#  ('tomorrow', 3),
#  ('te', 3),
#  ('chizmaga', 3),
#  ('released', 3),
#  ('nyt', 3),
#  ('scientist', 3),
#  ('brace', 3),
#  ('quocruz', 3),
#  ('hit', 3),
#  ('saying', 3),
#  ('shepmjs', 3),
#  ('wancruz', 3),
#  ('logical', 3),
#  ('either', 3),
#  ('tex', 3),
#  ('vetobeto', 3),
#  ('understand', 3),
#  ('especially', 3)]

# %%
pd.set_option('display.max_colwidth', -1)

# %%
# lets search for issues

tweets[tweets['text'].str.contains("immigrate")]
# Out:
#               location  \
# 3224  Myrtle Beach, SC
#
#                                                                                                                                                             text
# 3224  b'@iowahawkblog it is my intention to immigrate to and seek political asylum in texas. i  will be coming from sc. i h\xe2\x80\xa6 https://t.co/m17kfnyel8'

# %%
# Let's write a function to take care of the ISSUES
def replace_issues(text):
    
    text = text.lower()
    
    healthcare = ['affordable care act' , "healthcare", "aca"]
    taxes = ['tax', 'taxes']
    climatechange = ['climate', 'climatechange']
    bordercontrol = ['border', 'immigration', 'bordersecurity', 'borders']
    character = ['lyin', 'leader']
    
    for w in healthcare:
        try:
            text = text.replace(w, ' healthcare ')
        except:
            pass
    for w in taxes:
        try:
            text = text.replace(w, ' taxes ')
        except:
            pass
    for w in climatechange:
        try:
            text = text.replace(w, ' climatechange ')
        except:
            pass
    for w in bordercontrol:
        try:
            text = text.replace(w, ' bordercontrol ')
        except:
            pass

    for w in character:
        try:
            text = text.replace(w, ' character ')
        except:
            pass
    
    return text

# %%
# apply replace_issues() on each tweet
text_column = []
for t in tweets.itertuples():
    text = t.text
    new_text = replace_issues(text)
    text_column.append(new_text)

# %%
# replace old text with new text
tweets.text = text_column

# %%
# do another word count
# put all tweets together
text=tweets["text"].values.tolist()
text=" ".join(text)
text = text.lower()

# tokenize the text 
tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(text)

# counter object
words = Counter()

# update counter with new words
words.update(tokens)

# %%
# issues
issues = ['healthcare', 'taxes', 'climatechange', 'bordercontrol', 'character']

# %%
# lets do this again: remove stop words, single letter variable names
filter_words = Counter(x for x in tokens if x not in stopwords and x.isdigit() == False and len(x) != 1 and x.isalpha() == True and x in issues)

# %%
filter_words.most_common()[:]
# Out:
# [('healthcare', 730),
#  ('character', 289),
#  ('taxes', 196),
#  ('bordercontrol', 64),
#  ('climatechange', 36)]

# %% [markdown]
# Issues:
# * healthcare
# * character
# * taxes
# * bordercontrol

# %% [markdown]
# #### Calculate Lift for Candidate / Issue

# %% [markdown]
# Get count of tweets mentioning Beto / Cruz, and count of all tweets with Beto and/or Cruz in it

# %%
beto_count = 0
cruz_count = 0
n_tweets = 0
for t in tweets.itertuples():
    if 'beto' in t.text and 'cruz' in t.text:
        beto_count += 1
        cruz_count += 1
        n_tweets += 1
    elif 'beto' in t.text:
        beto_count += 1
        n_tweets += 1
    elif 'cruz' in t.text:
        cruz_count += 1        
        n_tweets += 1

# %%
n_tweets
# Out:
# 4677

# %% [markdown]
# Get count of tweets for each issue!

# %%
healthcare_count = 0
character_count = 0
taxes_count = 0
bordercontrol_count = 0
for t in tweets.itertuples():
    if 'healthcare' in t.text:
        healthcare_count += 1
    elif 'character' in t.text:
        character_count += 1
    elif 'taxes' in t.text:
        taxes_count += 1
    elif 'bordercontrol' in t.text:
        bordercontrol_count += 1

# %% [markdown]
# Get count of tweets with
#
# Beto/healthcare, Beto/character, Beto/taxes, Beto/bordercontrol
#
#
# Cruz/healthcare, Cruz/character, Cruz/taxes, Cruz/bordercontrol

# %%
# beto and issues
bh_count = 0
bc_count = 0
bt_count = 0
bb_count = 0

# cruz and issues
ch_count = 0
cc_count = 0
ct_count = 0
cb_count = 0

for t in tweets.itertuples():
    # beto
    if 'beto' in t.text and 'healthcare' in t.text:
        bh_count += 1
    if 'beto' in t.text and 'character' in t.text:
        bc_count += 1
    if 'beto' in t.text and 'taxes' in t.text:
        bt_count += 1
    if 'beto' in t.text and 'bordercontrol' in t.text:
        bb_count += 1
    
    # cruz
    if 'cruz' in t.text and 'healthcare' in t.text:
        ch_count += 1
    if 'cruz' in t.text and 'character' in t.text:
        cc_count += 1
    if 'cruz' in t.text and 'taxes' in t.text:
        ct_count += 1
    if 'cruz' in t.text and 'bordercontrol' in t.text:
        cb_count += 1

# %%
candidate_counts = [beto_count, cruz_count]
issue_counts = [healthcare_count, character_count, taxes_count, bordercontrol_count]
combo_counts = [bh_count, bc_count, bt_count, bb_count, ch_count, cc_count, ct_count, cb_count]
lifts = [] # order: [0] beto vs healthcare, [1] beto vs character, [2] beto vs taxes, [3] beto vs bordercontrol
           #        [4] cruz vs healthcare, [5] cruz vs character, [6] cruz vs taxes, [7] cruz vs bordercontrol
index = 0
for cand_count in candidate_counts:
    for issue_count in issue_counts:
        lifts.append( (len(tweets) * combo_counts[index]) / (cand_count * issue_count) )
    index +=1

# %%
lifts = np.reshape(lifts, (2, 4)).T # reshape for similarities matrix

# %%
similarities = pd.DataFrame(lifts, columns=['beto', 'cruz'], index=['healthcare', 'character', 'taxes', 'bordercontrol'])

# %%
similarities
# Out:
#                    beto      cruz
# healthcare     0.171859  0.635553
# character      0.440201  1.627908
# taxes          1.090934  4.034382
# bordercontrol  2.090956  7.732565

# %% [markdown]
# # Task D

# %% [markdown]
# ### Get dissimilarity matrix

# %%
attri_list=["beto","cruz","healthcare","character","taxes","bordercontrol"]

# %%
attri_combos = []
for i in range (len(attri_list)):
    for j in range (len(attri_list)):
        combo = (attri_list[i], attri_list[j])
        attri_combos.append(combo)

# %%
attri_combos
# Out:
# [('beto', 'beto'),
#  ('beto', 'cruz'),
#  ('beto', 'healthcare'),
#  ('beto', 'character'),
#  ('beto', 'taxes'),
#  ('beto', 'bordercontrol'),
#  ('cruz', 'beto'),
#  ('cruz', 'cruz'),
#  ('cruz', 'healthcare'),
#  ('cruz', 'character'),
#  ('cruz', 'taxes'),
#  ('cruz', 'bordercontrol'),
#  ('healthcare', 'beto'),
#  ('healthcare', 'cruz'),
#  ('healthcare', 'healthcare'),
#  ('healthcare', 'character'),
#  ('healthcare', 'taxes'),
#  ('healthcare', 'bordercontrol'),
#  ('character', 'beto'),
#  ('character', 'cruz'),
#  ('character', 'healthcare'),
#  ('character', 'character'),
#  ('character', 'taxes'),
#  ('character', 'bordercontrol'),
#  ('taxes', 'beto'),
#  ('taxes', 'cruz'),
#  ('taxes', 'healthcare'),
#  ('taxes', 'character'),
#  ('taxes', 'taxes'),
#  ('taxes', 'bordercontrol'),
#  ('bordercontrol', 'beto'),
#  ('bordercontrol', 'cruz'),
#  ('bordercontrol', 'healthcare'),
#  ('bordercontrol', 'character'),
#  ('bordercontrol', 'taxes'),
#  ('bordercontrol', 'bordercontrol')]

# %%
attri_combo_dict = {}
for a in attri_combos:
    attri_combo_dict[a] = 0

# %%
for a in attri_combos:
    for c in tweets["text"]:
        attri1 = a[0]
        attri2 = a[1]
        if attri1 in c and attri2 in c:
            attri_combo_dict[a] += 1

# %%
attri_combo_dict
# Out:
# {('beto', 'beto'): 3249,
#  ('beto', 'cruz'): 1913,
#  ('beto', 'healthcare'): 71,
#  ('beto', 'character'): 270,
#  ('beto', 'taxes'): 83,
#  ('beto', 'bordercontrol'): 14,
#  ('cruz', 'beto'): 1913,
#  ('cruz', 'cruz'): 3341,
#  ('cruz', 'healthcare'): 657,
#  ('cruz', 'character'): 87,
#  ('cruz', 'taxes'): 82,
#  ('cruz', 'bordercontrol'): 38,
#  ('healthcare', 'beto'): 71,
#  ('healthcare', 'cruz'): 657,
#  ('healthcare', 'healthcare'): 730,
#  ('healthcare', 'character'): 4,
#  ('healthcare', 'taxes'): 0,
#  ('healthcare', 'bordercontrol'): 0,
#  ('character', 'beto'): 270,
#  ('character', 'cruz'): 87,
#  ('character', 'healthcare'): 4,
#  ('character', 'character'): 289,
#  ('character', 'taxes'): 0,
#  ('character', 'bordercontrol'): 0,
#  ('taxes', 'beto'): 83,
#  ('taxes', 'cruz'): 82,
#  ('taxes', 'healthcare'): 0,
#  ('taxes', 'character'): 0,
#  ('taxes', 'taxes'): 115,
#  ('taxes', 'bordercontrol'): 1,
#  ('bordercontrol', 'beto'): 14,
#  ('bordercontrol', 'cruz'): 38,
#  ('bordercontrol', 'healthcare'): 0,
#  ('bordercontrol', 'character'): 0,
#  ('bordercontrol', 'taxes'): 1,
#  ('bordercontrol', 'bordercontrol'): 61}

# %%
attri_dict = {}
for b in attri_list:
    for c in tweets["text"]:
        if b in c:
            if b in attri_dict:
                attri_dict[b] += 1
            else:
                attri_dict[b] = 1

# %%
attri_dict
# Out:
# {'beto': 3249,
#  'cruz': 3341,
#  'healthcare': 730,
#  'character': 289,
#  'taxes': 115,
#  'bordercontrol': 61}

# %%
tot_number_of_tweets=n_tweets

# %%
tot_number_of_tweets=len(tweets)

# %%
tot_number_of_tweets
# Out:
# 5741

# %%
lifts_dict = {}
for a in attri_combo_dict:
    if a[0] == a[1]:
        lift = 0
    else:
        combo_count = attri_combo_dict[a]
        attri1_count = attri_dict[a[0]]
        attri2_count = attri_dict[a[1]]
        lift = (tot_number_of_tweets * combo_count) / (attri1_count * attri2_count)
    lifts_dict[a] = lift

# %%
matrix = []
row = -1
current_attri = ''
for combo in lifts_dict:
    attri = combo[0]
    lift = lifts_dict[combo]
    if attri == current_attri:
        matrix[row].append(lift)
    else:
        row += 1
        current_attri = attri
        matrix.append([])
        matrix[row].append(lift)

# %%
simi = pd.DataFrame(matrix, columns=attri_list, index=attri_list)

# %%
simi
# Out:
#                    beto      cruz  healthcare  character     taxes  \
# beto           0.000000  1.011757  0.171859    1.650835   1.275317
# cruz           1.011757  0.000000  1.546513    0.517288   1.225257
# healthcare     0.171859  1.546513  0.000000    0.108850   0.000000
# character      1.650835  0.517288  0.108850    0.000000   0.000000
# taxes          1.275317  1.225257  0.000000    0.000000   0.000000
# bordercontrol  0.405542  1.070446  0.000000    0.000000   0.818389
#
#                bordercontrol
# beto           0.405542
# cruz           1.070446
# healthcare     0.000000
# character      0.000000
# taxes          0.818389
# bordercontrol  0.000000

# %%
#dissimilarity
dis=matrix
for i in range (len(matrix)):
    for j in range (len(matrix[i])):
        if matrix[i][j] != 0:
            dis[i][j] = 1/matrix[i][j]

# %%
dissimilarity = pd.DataFrame(dis, columns=attri_list, index=attri_list)

# %%
dissimilarity
# Out:
#                    beto      cruz  healthcare  character     taxes  \
# beto           0.000000  1.213232  7.142444    0.743561   0.962503
# cruz           1.213232  0.000000  0.793719    2.372945   1.001828
# healthcare     7.142444  0.793719  0.000000    11.276994  0.000000
# character      0.743561  2.372945  11.276994   0.000000   0.000000
# taxes          0.962503  1.001828  0.000000    0.000000   0.000000
# bordercontrol  3.026803  1.146715  0.000000    0.000000   1.499893
#
#                bordercontrol
# beto           3.026803
# cruz           1.146715
# healthcare     0.000000
# character      0.000000
# taxes          1.499893
# bordercontrol  0.000000

# %% [markdown]
# ### Plot MDS Map

# %%
from sklearn import manifold
from sklearn.metrics import euclidean_distances
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
mds = manifold.MDS(n_components=2, max_iter=3000, eps=1e-9,
                   dissimilarity="precomputed", n_jobs=1)
pos = mds.fit(dis).embedding_

# %%
dissimilarity = dissimilarity.max() / similarities * 100
dissimilarity[np.isinf(dissimilarity)] = 0

# Plot the edges
start_idx, end_idx = np.where(pos)

values = np.abs(dissimilarity)

# %%
fig = plt.figure(1)
ax = plt.axes([0., 0., 1., 1.])

s = 100

plt.scatter(pos[:, 0], pos[:, 1], color='turquoise', s=s, lw=0, label='MDS')
plt.legend(scatterpoints=1, loc='best', shadow=False)

for label, x, y in zip(attri_list, pos[:, 0], pos[:, 1]):
    plt.annotate(
        label,
        xy = (x, y), xytext = (-20, 20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

plt.show()

# %% [markdown]
# Healthcare is very far away from both Cruz and Beto. This could be because healthcare is a topic that could be talked about by itself a lot without mention of cruz and beto. Both Cruz and Beto, seeing that healthcare is a very talked about topic, could jump on this and do a better job associating their positions on healthcare with the public.
