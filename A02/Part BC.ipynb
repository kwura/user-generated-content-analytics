# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# Perform lift and sentiment analysis on each candidate and issue:
# ![title](taskC.png)
#
# To do the above analysis, you will have to write a script to parse each tweet and extract parts that pertain to a candidate and attribute. Provide details of how you accomplished this task in a script.

# %%
# read the csv into a dataframe
tweets = pd.read_csv("tot_tweets.csv")
tweets = tweets.drop(columns=['id'])

# %%
tweets.head()
# Out:
#          location  \
# 0  Tennessee, USA
# 1  NaN
# 2  NaN
# 3  America
# 4  West Texas
#
#                                                                                                                                                                         text
# 0  b"RT @AliAdair22: \xf0\x9f\x90\xa6Next, Beto O'Rourke @BetoORourke, running for U.S. Senate in #Texas. Please follow, tweet, contribute, volunteer, anything\xe2\x80\xa6"
# 1  b"RT @AliAdair22: \xf0\x9f\x90\xa6Next, Beto O'Rourke @BetoORourke, running for U.S. Senate in #Texas. Please follow, tweet, contribute, volunteer, anything\xe2\x80\xa6"
# 2  b"Ted Cruz, Beto O'Rourke try to rally Latino voters in Texas Senate race https://t.co/EHvO0Zz7yh #FoxNews @MRiveraFoxNews"
# 3  b'RT @RonNehring: Third poll now showing Cruz with 8 or 9 point solid lead over Beto O\xe2\x80\x99Rourke (D-Hollywood). Follows Quinnipiac and NY Times\xe2\x80\xa6'
# 4  b'Beto O\xe2\x80\x99Rourke, the Democratic congressman from El Paso, has made the Texas race for US Senate one of the most widel\xe2\x80\xa6 https://t.co/f9i3QqeJ6U'

# %%
# Let's write a function to take care of the names
def replace_names(text):
    
    text = text.lower()
    
    beto_words = ['@betoorourke' , "beto o'rourke", "o'rourke", 'rourke', 'beto']
    cruz_words = ['@tedcruz', 'ted cruz', 'ted', 'cruz']
    
    for w in beto_words:
        try:
            text = text.replace(w, ' beto ')
        except:
            pass
    for w in cruz_words:
        try:
            text = text.replace(w, ' cruz ')
        except:
            pass
    
    return text

# %%
# apply replace_names() on each tweet
text_column = []
for t in tweets.itertuples():
    text = t.text
    new_text = replace_names(text)
    text_column.append(new_text)

# %%
# replace old text with new text
tweets.text = text_column

# %%
for i in tweets.itertuples():
    text = i.text
    print(text)
    break
# Out:
# b"rt @aliadair22: \xf0\x9f\x90\xa6next,   beto     beto  , running for u.s. senate in #texas. please follow, tweet, contribute, volunteer, anything\xe2\x80\xa6"

# %%
# word frequency
# grab word frequency using nltk library
import nltk
# stop words
from nltk.corpus import stopwords

# %%
# put all tweets together
text=tweets["text"].values.tolist()
text=" ".join(text)
text = text.lower()

# %%
# tokenize the text 
tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(text)

# %%
# let's do a word count
from collections import Counter

# counter object
words = Counter()

# update counter with new words
words.update(tokens)

# %%
# first order check
words.most_common()[:10]
# Out:
# [('xe2', 6577),
#  ('x80', 6452),
#  ('b', 5743),
#  ('rt', 4791),
#  ('beto', 4561),
#  ('cruz', 4463),
#  ('the', 4411),
#  ('xa6', 3879),
#  ('texas', 3135),
#  ('in', 3112)]

# %%
# store the stop words
stopwords = stopwords.words('english')[:]

# %%
# lets do this again: remove stop words, single letter variable names
filter_words = Counter(x for x in tokens if x not in stopwords and x.isdigit() == False and len(x) != 1 and x.isalpha() == True)

# %%
filter_words.most_common()[:1000]
# Out:
# [('rt', 4791),
#  ('beto', 4561),
#  ('cruz', 4463),
#  ('texas', 3135),
#  ('senate', 3003),
#  ('https', 2088),
#  ('co', 2007),
#  ('race', 1956),
#  ('vote', 950),
#  ('single', 785),
#  ('msnbc', 735),
#  ('word', 722),
#  ('win', 703),
#  ('every', 662),
#  ('care', 656),
#  ('repeal', 652),
#  ('act', 652),
#  ('pre', 652),
#  ('insis', 651),
#  ('affordable', 651),
#  ('including', 651),
#  ('protections', 651),
#  ('existing', 650),
#  ('condi', 650),
#  ('debate', 502),
#  ('nplease', 491),
#  ('believe', 487),
#  ('retweet', 483),
#  ('sample', 483),
#  ('bigger', 479),
#  ('size', 478),
#  ('guy', 401),
#  ('leads', 352),
#  ('show', 345),
#  ('skateboard', 343),
#  ('still', 337),
#  ('side', 336),
#  ('election', 334),
#  ('polling', 331),
#  ('skates', 327),
#  ('across', 327),
#  ('stage', 327),
#  ('hoping', 327),
#  ('dont', 327),
#  ('history', 319),
#  ('texassenate', 301),
#  ('million', 289),
#  ('want', 256),
#  ('looking', 241),
#  ('cbsnews', 238),
#  ('ahead', 237),
#  ('problem', 237),
#  ('integrity', 235),
#  ('serious', 232),
#  ('becaus', 232),
#  ('campaign', 224),
#  ('poll', 222),
#  ('says', 215),
#  ('proud', 211),
#  ('quarter', 210),
#  ('follow', 204),
#  ('leader', 198),
#  ('raised', 193),
#  ('ask', 189),
#  ('question', 188),
#  ('tried', 187),
#  ('importance', 186),
#  ('interrupt', 185),
#  ('jason', 185),
#  ('moderator', 185),
#  ('remaining', 185),
#  ('fundraising', 183),
#  ('seat', 180),
#  ('make', 180),
#  ('friends', 177),
#  ('amazing', 172),
#  ('wi', 169),
#  ('dominates', 165),
#  ('taxes', 163),
#  ('winning', 162),
#  ('money', 159),
#  ('salon', 155),
#  ('record', 153),
#  ('republican', 152),
#  ('us', 149),
#  ('amhotflash', 147),
#  ('voters', 146),
#  ('senator', 145),
#  ('vs', 144),
#  ('nwe', 144),
#  ('country', 138),
#  ('really', 137),
#  ('rep', 137),
#  ('chance', 136),
#  ('get', 129),
#  ('expensive', 128),
#  ('wants', 128),
#  ('raises', 128),
#  ('johncornyn', 124),
#  ('sen', 124),
#  ('hey', 123),
#  ('points', 122),
#  ('democrat', 120),
#  ('could', 117),
#  ('yes', 115),
#  ('mr', 113),
#  ('try', 111),
#  ('latino', 111),
#  ('trump', 111),
#  ('rally', 110),
#  ('need', 106),
#  ('via', 104),
#  ('realdonaldtrump', 104),
#  ('democratic', 102),
#  ('nhttps', 99),
#  ('keep', 99),
#  ('would', 98),
#  ('congressman', 97),
#  ('going', 96),
#  ('texasdebate', 95),
#  ('attack', 94),
#  ('calling', 94),
#  ('worth', 94),
#  ('texans', 90),
#  ('polls', 89),
#  ('clear', 89),
#  ('delusional', 88),
#  ('candidate', 87),
#  ('reuters', 87),
#  ('cattharmony', 87),
#  ('eough', 87),
#  ('one', 85),
#  ('closing', 85),
#  ('xba', 85),
#  ('said', 83),
#  ('raise', 82),
#  ('triples', 81),
#  ('rjc', 81),
#  ('cut', 81),
#  ('remarks', 81),
#  ('races', 80),
#  ('think', 79),
#  ('midterm', 78),
#  ('records', 77),
#  ('buckle', 77),
#  ('kids', 77),
#  ('foxnews', 76),
#  ('gop', 76),
#  ('trailing', 74),
#  ('aggressive', 73),
#  ('clock', 73),
#  ('aca', 72),
#  ('alone', 71),
#  ('issue', 71),
#  ('valu', 70),
#  ('people', 70),
#  ('years', 69),
#  ('big', 69),
#  ('hollywood', 68),
#  ('like', 68),
#  ('amp', 68),
#  ('ndemturds', 68),
#  ('counting', 68),
#  ('look', 67),
#  ('rival', 67),
#  ('went', 67),
#  ('gets', 65),
#  ('ronnehring', 64),
#  ('lead', 64),
#  ('fortexas', 64),
#  ('media', 64),
#  ('third', 63),
#  ('tonight', 60),
#  ('world', 60),
#  ('maga', 60),
#  ('losing', 60),
#  ('good', 59),
#  ('great', 59),
#  ('past', 58),
#  ('profiles', 57),
#  ('wait', 57),
#  ('covering', 57),
#  ('american', 57),
#  ('essenviews', 57),
#  ('democracy', 57),
#  ('rule', 57),
#  ('new', 56),
#  ('coverag', 56),
#  ('reaction', 56),
#  ('experiment', 56),
#  ('exception', 56),
#  ('sacre', 55),
#  ('chances', 54),
#  ('breaks', 54),
#  ('beating', 53),
#  ('come', 53),
#  ('quinnipiac', 52),
#  ('last', 52),
#  ('remote', 52),
#  ('star', 52),
#  ('quinnipiacpoll', 52),
#  ('point', 51),
#  ('time', 51),
#  ('slate', 51),
#  ('cementing', 51),
#  ('using', 51),
#  ('crew', 50),
#  ('finds', 50),
#  ('republicans', 49),
#  ('stalls', 49),
#  ('rather', 48),
#  ('president', 48),
#  ('probably', 48),
#  ('support', 48),
#  ('nnnnguy', 48),
#  ('charlesppierce', 48),
#  ('happens', 47),
#  ('nationwide', 47),
#  ('governor', 47),
#  ('jmcfeels', 47),
#  ('net', 47),
#  ('nnow', 47),
#  ('talk', 46),
#  ('independent', 46),
#  ('earns', 46),
#  ('endorsement', 45),
#  ('safetypindaily', 44),
#  ('lyin', 44),
#  ('mess', 43),
#  ('tuesday', 43),
#  ('cwebbonline', 42),
#  ('fingertips', 42),
#  ('le', 42),
#  ('cnnpolitics', 42),
#  ('previous', 41),
#  ('year', 41),
#  ('wipes', 41),
#  ('floor', 41),
#  ('embattled', 41),
#  ('epic', 41),
#  ('please', 40),
#  ('shattering', 40),
#  ('needs', 40),
#  ('america', 39),
#  ('votes', 39),
#  ('elect', 39),
#  ('mean', 39),
#  ('partisan', 39),
#  ('stop', 38),
#  ('choice', 38),
#  ('democrats', 38),
#  ('nasty', 38),
#  ('despite', 38),
#  ('two', 37),
#  ('state', 37),
#  ('txsen', 37),
#  ('hear', 37),
#  ('endorse', 37),
#  ('circus', 37),
#  ('rawstory', 37),
#  ('looks', 36),
#  ('cnn', 36),
#  ('toughastexas', 36),
#  ('interesting', 36),
#  ('supporting', 35),
#  ('trumptrain', 35),
#  ('walkawayfromdemocrats', 35),
#  ('candy', 35),
#  ('bordersecurity', 35),
#  ('lawenforcement', 35),
#  ('advocate', 35),
#  ('ouesvpzayf', 35),
#  ('today', 34),
#  ('political', 34),
#  ('called', 34),
#  ('kennedy', 34),
#  ('latest', 34),
#  ('ran', 34),
#  ('climate', 34),
#  ('abolish', 34),
#  ('watched', 34),
#  ('wish', 34),
#  ('final', 33),
#  ('tax', 33),
#  ('thisweekabc', 32),
#  ('go', 32),
#  ('facts', 32),
#  ('jfk', 32),
#  ('cuts', 32),
#  ('dodge', 32),
#  ('excus', 32),
#  ('seconds', 32),
#  ('battle', 32),
#  ('breaking', 31),
#  ('nickname', 31),
#  ('impeachment', 31),
#  ('exactly', 31),
#  ('key', 30),
#  ('thinks', 30),
#  ('old', 30),
#  ('criticizes', 30),
#  ('days', 30),
#  ('made', 29),
#  ('raising', 29),
#  ('paulmayatl', 29),
#  ('type', 29),
#  ('generational', 29),
#  ('disaster', 29),
#  ('brings', 29),
#  ('change', 29),
#  ('redo', 29),
#  ('realjameswoods', 29),
#  ('fun', 29),
#  ('running', 28),
#  ('edwardthardy', 28),
#  ('jokes', 28),
#  ('taken', 28),
#  ('weeks', 28),
#  ('de', 28),
#  ('blisstabitha', 28),
#  ('beat', 28),
#  ('man', 28),
#  ('el', 27),
#  ('day', 27),
#  ('red', 27),
#  ('stale', 27),
#  ('recent', 27),
#  ('repor', 27),
#  ('fund', 27),
#  ('reached', 27),
#  ('tha', 27),
#  ('news', 26),
#  ('chappaquiddick', 26),
#  ('college', 26),
#  ('run', 26),
#  ('swinging', 26),
#  ('paso', 25),
#  ('let', 25),
#  ('obvious', 25),
#  ('hea', 25),
#  ('voter', 24),
#  ('important', 24),
#  ('call', 24),
#  ('joe', 24),
#  ('midterms', 24),
#  ('niro', 24),
#  ('reliable', 24),
#  ('candidates', 24),
#  ('fact', 24),
#  ('attacks', 24),
#  ('times', 23),
#  ('reminder', 23),
#  ('dems', 23),
#  ('presidenttrump', 23),
#  ('cocaine', 23),
#  ('snuffed', 23),
#  ('unitevotered', 23),
#  ('joanofamerica', 23),
#  ('extremely', 23),
#  ('qualified', 23),
#  ('supporti', 23),
#  ('watch', 23),
#  ('came', 23),
#  ('ny', 22),
#  ('house', 22),
#  ('bet', 22),
#  ('take', 22),
#  ('immigration', 22),
#  ('caucasoid', 22),
#  ('iberians', 22),
#  ('larping', 22),
#  ('amerindians', 22),
#  ('ambiguous', 22),
#  ('ethnic', 22),
#  ('boom', 22),
#  ('comi', 22),
#  ('honest', 22),
#  ('showing', 21),
#  ('citybureaucrat', 21),
#  ('meto', 21),
#  ('hard', 21),
#  ('first', 21),
#  ('abpumfmcjm', 21),
#  ('asserts', 21),
#  ('hardball', 21),
#  ('live', 20),
#  ('night', 20),
#  ('later', 20),
#  ('pres', 20),
#  ('embarks', 20),
#  ('swing', 20),
#  ('keeping', 20),
#  ('continuing', 20),
#  ('xdb', 20),
#  ('tweet', 19),
#  ('solid', 19),
#  ('follows', 19),
#  ('politics', 19),
#  ('lose', 19),
#  ('voting', 19),
#  ('see', 19),
#  ('event', 19),
#  ('youtube', 19),
#  ('nickmadincea', 19),
#  ('thursday', 19),
#  ('thinkprogress', 19),
#  ('dallas', 18),
#  ('know', 18),
#  ('campaigns', 18),
#  ('states', 18),
#  ('lying', 18),
#  ('tough', 18),
#  ('shortly', 18),
#  ('contribute', 17),
#  ('anything', 17),
#  ('even', 17),
#  ('everyone', 17),
#  ('holds', 17),
#  ('send', 17),
#  ('volunteer', 16),
#  ('say', 16),
#  ('dem', 16),
#  ('video', 16),
#  ('second', 16),
#  ('promised', 16),
#  ('dude', 16),
#  ('likely', 16),
#  ('right', 16),
#  ('leading', 16),
#  ('late', 16),
#  ('entering', 15),
#  ('white', 15),
#  ('better', 15),
#  ('txpolitics', 15),
#  ('morningjoe', 15),
#  ('incumbent', 14),
#  ('october', 14),
#  ('montana', 14),
#  ('robert', 14),
#  ('visi', 14),
#  ('move', 14),
#  ('corpus', 14),
#  ('christi', 14),
#  ('tennessee', 14),
#  ('deadlinewh', 14),
#  ('game', 14),
#  ('outfrontcnn', 14),
#  ('comes', 14),
#  ('xef', 13),
#  ('someone', 13),
#  ('coming', 13),
#  ('tx', 13),
#  ('hope', 13),
#  ('wins', 13),
#  ('asks', 13),
#  ('nvote', 13),
#  ('campuses', 13),
#  ('walk', 13),
#  ('shoes', 13),
#  ('energy', 13),
#  ('pas', 13),
#  ('thecut', 13),
#  ('abcpolitics', 13),
#  ('non', 13),
#  ('txgov', 13),
#  ('txpol', 13),
#  ('joetalkshow', 13),
#  ('hi', 13),
#  ('deep', 13),
#  ('lol', 12),
#  ('forsenate', 12),
#  ('topics', 12),
#  ('dreamers', 12),
#  ('help', 12),
#  ('turnout', 12),
#  ('ntexas', 12),
#  ('disrespectful', 12),
#  ('drive', 12),
#  ('elections', 12),
#  ('mind', 12),
#  ('consider', 12),
#  ('also', 12),
#  ('mtp', 12),
#  ('nation', 12),
#  ('charge', 12),
#  ('markknoller', 12),
#  ('ar', 12),
#  ('nails', 12),
#  ('testy', 12),
#  ('challenger', 11),
#  ('lot', 11),
#  ('family', 11),
#  ('vicenews', 11),
#  ('away', 11),
#  ('donaldjtrumpjr', 11),
#  ('drtookanauer', 11),
#  ('ok', 11),
#  ('nfl', 11),
#  ('kneeling', 11),
#  ('fla', 11),
#  ('liberal', 11),
#  ('blue', 11),
#  ('things', 11),
#  ('fake', 11),
#  ('thanks', 11),
#  ('stars', 11),
#  ('bright', 11),
#  ('heart', 11),
#  ('nhos', 11),
#  ('nice', 11),
#  ('gloves', 11),
#  ('making', 11),
#  ('dishonest', 11),
#  ('frankluntz', 10),
#  ('focus', 10),
#  ('group', 10),
#  ('shows', 10),
#  ('bubble', 10),
#  ('anyone', 10),
#  ('iii', 10),
#  ('jaketapper', 10),
#  ('way', 10),
#  ('michaelavenatti', 10),
#  ('close', 10),
#  ('potus', 10),
#  ('less', 10),
#  ('keeptexasred', 10),
#  ('sure', 10),
#  ('sense', 10),
#  ('texastribune', 10),
#  ('senat', 10),
#  ('collegedems', 10),
#  ('stanc', 10),
#  ('uni', 10),
#  ('stands', 10),
#  ('xda', 10),
#  ('results', 9),
#  ('early', 9),
#  ('watching', 9),
#  ('draw', 9),
#  ('full', 9),
#  ('true', 9),
#  ('born', 9),
#  ('canada', 9),
#  ('trying', 9),
#  ('presidential', 9),
#  ('took', 9),
#  ('give', 9),
#  ('xbc', 9),
#  ('job', 9),
#  ('article', 9),
#  ('may', 9),
#  ('mailonline', 9),
#  ('ni', 9),
#  ('hispanic', 9),
#  ('lags', 9),
#  ('next', 9),
#  ('name', 9),
#  ('never', 9),
#  ('ad', 9),
#  ('nquote', 9),
#  ('voteredtosaveamerica', 9),
#  ('future', 9),
#  ('deciding', 9),
#  ('ca', 9),
#  ('three', 9),
#  ('sent', 8),
#  ('ties', 8),
#  ('wealthy', 8),
#  ('scrutiny', 8),
#  ('ads', 8),
#  ('wall', 8),
#  ('thehill', 8),
#  ('smart', 8),
#  ('month', 8),
#  ('tight', 8),
#  ('ev', 8),
#  ('inc', 8),
#  ('inside', 8),
#  ('knew', 8),
#  ('party', 8),
#  ('calls', 8),
#  ('seen', 8),
#  ('behind', 8),
#  ('happy', 8),
#  ('many', 8),
#  ('rakes', 8),
#  ('stretch', 8),
#  ('conservative', 8),
#  ('turn', 8),
#  ('love', 8),
#  ('real', 8),
#  ('science', 8),
#  ('human', 8),
#  ('death', 8),
#  ('endorses', 8),
#  ('half', 8),
#  ('na', 8),
#  ('missed', 8),
#  ('profjkaiyer', 8),
#  ('table', 8),
#  ('basically', 8),
#  ('takeaways', 8),
#  ('michaelskolnik', 8),
#  ('cor', 8),
#  ('historically', 8),
#  ('lowest', 8),
#  ('changes', 8),
#  ('hundreds', 8),
#  ('personal', 8),
#  ('commissioner', 8),
#  ('belong', 7),
#  ('weekend', 7),
#  ('nand', 7),
#  ('national', 7),
#  ('business', 7),
#  ('heard', 7),
#  ('actually', 7),
#  ('maybe', 7),
#  ('include', 7),
#  ('matter', 7),
#  ('taking', 7),
#  ('makes', 7),
#  ('florida', 7),
#  ('bobdrummond', 7),
#  ('cfgaction', 7),
#  ('wpaintel', 7),
#  ('nballot', 7),
#  ('comparison', 7),
#  ('millions', 7),
#  ('hate', 7),
#  ('francis', 7),
#  ('loses', 7),
#  ('haul', 7),
#  ('enters', 7),
#  ('low', 7),
#  ('wrong', 7),
#  ('spent', 7),
#  ('arizona', 7),
#  ('shot', 7),
#  ('talks', 7),
#  ('representative', 7),
#  ('face', 7),
#  ('put', 7),
#  ('talking', 7),
#  ('lauralitvan', 7),
#  ('marsha', 7),
#  ('blackburn', 7),
#  ('michael', 7),
#  ('pts', 7),
#  ('authenticity', 7),
#  ('got', 7),
#  ('houston', 7),
#  ('elec', 7),
#  ('mania', 7),
#  ('town', 7),
#  ('socialist', 7),
#  ('esquire', 7),
#  ('wcpy', 7),
#  ('electoral', 7),
#  ('message', 7),
#  ('allcharisma', 7),
#  ('yikes', 7),
#  ('cand', 7),
#  ('land', 7),
#  ('education', 7),
#  ('tale', 7),
#  ('rallies', 7),
#  ('daughter', 7),
#  ('goes', 7),
#  ('liked', 7),
#  ('trumpology', 7),
#  ('thousa', 7),
#  ('st', 7),
#  ('ringer', 7),
#  ('lots', 6),
#  ('cook', 6),
#  ('tv', 6),
#  ('la', 6),
#  ('etc', 6),
#  ('choose', 6),
#  ('much', 6),
#  ('defeat', 6),
#  ('texan', 6),
#  ('txlege', 6),
#  ('soros', 6),
#  ('beta', 6),
#  ('nytimes', 6),
#  ('well', 6),
#  ('amervoices', 6),
#  ('asked', 6),
#  ('crazy', 6),
#  ('car', 6),
#  ('saw', 6),
#  ('hopeful', 6),
#  ('july', 6),
#  ('september', 6),
#  ('thedemcoalition', 6),
#  ('joseph', 6),
#  ('votefor', 6),
#  ('gap', 6),
#  ('several', 6),
#  ('months', 6),
#  ('wife', 6),
#  ('accomplished', 6),
#  ('represent', 6),
#  ('vo', 6),
#  ('hell', 6),
#  ('cherijacobus', 6),
#  ('must', 6),
#  ('coverage', 6),
#  ('thing', 6),
#  ('danpatrick', 6),
#  ('large', 6),
#  ('attacked', 6),
#  ('paris', 6),
#  ('accord', 6),
#  ('millennial', 6),
#  ('cringed', 6),
#  ('buy', 6),
#  ('november', 6),
#  ('mikey', 6),
#  ('kiss', 6),
#  ('issues', 6),
#  ('ncreepy', 6),
#  ('porn', 6),
#  ('lawyer', 6),
#  ('avenatti', 6),
#  ('ncongratulations', 6),
#  ('hall', 6),
#  ('joke', 6),
#  ('peter', 6),
#  ('brown', 6),
#  ('discuss', 6),
#  ('texasgovernor', 6),
#  ('plumme', 6),
#  ('six', 6),
#  ('map', 6),
#  ('generation', 6),
#  ('expert', 6),
#  ('trad', 6),
#  ('rodents', 6),
#  ('blind', 6),
#  ('squirrel', 6),
#  ('missing', 6),
#  ('poor', 6),
#  ('trumpchatting', 6),
#  ('noto', 6),
#  ('square', 6),
#  ('headlines', 6),
#  ('stil', 5),
#  ('declines', 5),
#  ('hour', 5),
#  ('th', 5),
#  ('happened', 5),
#  ('boy', 5),
#  ('thought', 5),
#  ('opponent', 5),
#  ('men', 5),
#  ('sets', 5),
#  ('story', 5),
#  ('press', 5),
#  ('posting', 5),
#  ('wheel', 5),
#  ('seems', 5),
#  ('fight', 5),
#  ('dallasnews', 5),
#  ('tomhfh', 5),
#  ('term', 5),
#  ('donald', 5),
#  ('nnothing', 5),
#  ('gerrymandering', 5),
#  ('cr', 5),
#  ('signs', 5),
#  ('university', 5),
#  ('bluewave', 5),
#  ('among', 5),
#  ('stand', 5),
#  ('abc', 5),
#  ('anti', 5),
#  ('giving', 5),
#  ('inser', 5),
#  ('contentious', 5),
#  ('takes', 5),
#  ('though', 5),
#  ('network', 5),
#  ('larger', 5),
#  ('irish', 5),
#  ('speaks', 5),
#  ('im', 5),
#  ('sign', 5),
#  ('opening', 5),
#  ('nine', 5),
#  ('cannot', 5),
#  ('san', 5),
#  ('antonio', 5),
#  ('tovictory', 5),
#  ('common', 5),
#  ('rich', 5),
#  ('todosono', 5),
#  ('harder', 5),
#  ('mediajuggernaut', 5),
#  ('austin', 5),
#  ('que', 5),
#  ('trust', 5),
#  ('line', 5),
#  ('stevekling', 5),
#  ('wasting', 5),
#  ('registration', 5),
#  ('newshour', 5),
#  ('reuterspolitics', 5),
#  ('sends', 5),
#  ('quite', 5),
#  ('possibly', 5),
#  ('spar', 5),
#  ('hamster', 5),
#  ('investments', 5),
#  ('exploiting', 5),
#  ('omefwunxnz', 5),
#  ('fort', 5),
#  ('jilevin', 5),
#  ('matthewamiller', 5),
#  ('normal', 5),
#  ('andro', 5),
#  ('nothing', 5),
#  ('runswitchpr', 5),
#  ('debt', 5),
#  ('xaf', 5),
#  ('wfaa', 4),
#  ('gxnrzdjhid', 4),
#  ('resist', 4),
#  ('journal', 4),
#  ('dtxergaomnes', 4),
#  ('nif', 4),
#  ('asking', 4),
#  ('donations', 4),
#  ('imagine', 4),
#  ('oklahoma', 4),
#  ('caring', 4),
#  ('inst', 4),
#  ('border', 4),
#  ('bad', 4),
#  ('since', 4),
#  ('discussing', 4),
#  ('explains', 4),
#  ('explain', 4),
#  ('gotten', 4),
#  ('fewer', 4),
#  ('five', 4),
#  ('remember', 4),
#  ('primary', 4),
#  ('cru', 4),
#  ('ntennessee', 4),
#  ('paul', 4),
#  ('dailymail', 4),
#  ('htt', 4),
#  ('wan', 4),
#  ('period', 4),
#  ('missouri', 4),
#  ('veto', 4),
#  ('gonna', 4),
#  ('back', 4),
#  ('wonder', 4),
#  ('seats', 4),
#  ('currently', 4),
#  ('getting', 4),
#  ('ever', 4),
#  ('nthe', 4),
#  ('done', 4),
#  ('hold', 4),
#  ('annatinsley', 4),
#  ('guide', 4),
#  ('momentum', 4),
#  ('puts', 4),
#  ('double', 4),
#  ('hillary', 4),
#  ('use', 4),
#  ('meant', 4),
#  ('woman', 4),
#  ('yeah', 4),
#  ('bostonglobe', 4),
#  ('fo', 4),
#  ('recognition', 4),
#  ('midtermelections', 4),
#  ('pushing', 4),
#  ('always', 4),
#  ('spanish', 4),
#  ('worried', 4),
#  ('leaders', 4),
#  ('auburngirlx', 4),
#  ('something', 4),
#  ('usrealitycheck', 4),
#  ('deniers', 4),
#  ('data', 4),
#  ('team', 4),
#  ('changing', 4),
#  ('favorite', 4),
#  ('blood', 4),
#  ('fireworks', 4),
#  ('around', 4),
#  ('part', 4),
#  ('listen', 4),
#  ('opportunity', 4),
#  ('alliance', 4),
#  ('truth', 4),
#  ('giltpolitics', 4),
#  ('mi', 4),
#  ('questioning', 4),
#  ('slogan', 4),
#  ('liberals', 4),
#  ('giddy', 4),
#  ('thi', 4),
#  ('without', 4),
#  ('legislation', 4),
#  ('obama', 4),
#  ('authentically', 4),
#  ('cool', 4),
#  ('gave', 4),
#  ('et', 4),
#  ('reflects', 4),
#  ('demographic', 4),
#  ('divide', 4),
#  ('repeat', 4),
#  ('instead', 4),
#  ('worked', 4),
#  ('healthcare', 4),
#  ('leadership', 4),
#  ('whe', 4),
#  ('week', 4),
#  ('nevada', 4),
#  ('spike', 4),
#  ('certainly', 4),
#  ('zerlinamaxwell', 4),
#  ('bill', 4),
#  ('gt', 4),
#  ('nthis', 4),
#  ('honor', 4),
#  ('borrows', 4),
#  ('short', 4),
#  ('hammered', 4),
#  ('absolutely', 4),
#  ('tweets', 4),
#  ('mocking', 4),
#  ('arizonans', 4),
#  ('abcworldnews', 4),
#  ('demo', 4),
#  ('thirdbennn', 4),
#  ('mrmiguelsuazo', 4),
#  ('romanmcallen', 4),
#  ('railroad', 4),
#  ('qhtvlssryv', 4),
#  ('thoughts', 3),
#  ('york', 3),
#  ('strategy', 3),
#  ('hearing', 3),
#  ('pacs', 3),
#  ('breakdown', 3),
#  ('according', 3),
#  ('houstonchron', 3),
#  ('kick', 3),
#  ('nbig', 3),
#  ('text', 3),
#  ('decide', 3),
#  ('amarporashona', 3),
#  ('position', 3),
#  ('challenge', 3),
#  ('worl', 3),
#  ('dmn', 3),
#  ('towards', 3),
#  ('laugh', 3),
#  ('differentia', 3),
#  ('campa', 3),
#  ('oh', 3),
#  ('easily', 3),
#  ('spending', 3),
#  ('tomorrow', 3),
#  ('te', 3),
#  ('chizmaga', 3),
#  ('released', 3),
#  ('nyt', 3),
#  ('scientist', 3),
#  ('brace', 3),
#  ('quo', 3),
#  ('hit', 3),
#  ('saying', 3),
#  ('shepmjs', 3),
#  ('logical', 3),
#  ('either', 3),
#  ('tex', 3),
#  ('understand', 3),
#  ('especially', 3),
#  ('california', 3),
#  ('high', 3),
#  ('gain', 3),
#  ('definitely', 3),
#  ('set', 3),
#  ('serve', 3),
#  ('continues', 3),
#  ('gerrymander', 3),
#  ('jordan', 3)]

# %%
pd.set_option('display.max_colwidth', -1)

# %%
# lets search for issues
tweets[tweets['text'].str.contains("")]
# Out:
#                                 location  \
# 0     Tennessee, USA
# 1     NaN
# 2     NaN
# 3     America
# 4     West Texas
# 5     Dallas, TX
# 6     NaN
# 7     Atlanta, GA
# 8     Oregon
# 9     Australia
# 10    PALM HARBOR FL
# 11    Illinois
# 12    NaN
# 13    San Antonio, Texas
# 14    Austin, Texas
# 15    NaN
# 16    Toronto, Ontario, Canada
# 17    Atlanta, Georgia
# 18    NaN
# 19    Texas
# 20    Dallas
# 21    Del Mar, CA
# 22    Washington, DC
# 23    NaN
# 24    Deep in the 💙 of Texas 🇨🇱
# 25    NaN
# 26    Mesa, AZ
# 27    NaN
# 28    NaN
# 29    Property of @HendriWigunah
# ...                          ...
# 5711  NaN
# 5712  NaN
# 5713  Newton, MA
# 5714  North Carolina, USA
# 5715  NaN
# 5716  NaN
# 5717  United States
# 5718  Poughkeepsie, NY
# 5719  Toledo District, Belize
# 5720  Saint Marys, GA
# 5721  Texas, USA
# 5722  Riverside, California
# 5723  NaN
# 5724  NaN
# 5725  United States
# 5726  Dallas, TX
# 5727  Texas
# 5728  newport news
# 5729  Resist, CA
# 5730  South Carolina, USA
# 5731  United States
# 5732  North Central, Philadelphia
# 5733  NaN
# 5734  Las Vegas, NV/ Lansing, MI
# 5735  (ISFJ-A)
# 5736  Ozorków gmina, Polska
# 5737  Poteau, OK
# 5738  Kansas, unfortunately
# 5739  NaN
# 5740  NaN
#
#                                                                                                                                                                                                                                  text
# 0     b"rt @aliadair22: \xf0\x9f\x90\xa6next,   beto     beto  , running for u.s. senate in #texas. please follow, tweet, contribute, volunteer, anything\xe2\x80\xa6"
# 1     b"rt @aliadair22: \xf0\x9f\x90\xa6next,   beto     beto  , running for u.s. senate in #texas. please follow, tweet, contribute, volunteer, anything\xe2\x80\xa6"
# 2     b"  cruz  ,   beto   try to rally latino voters in texas senate race https://t.co/ehvo0zz7yh #foxnews @mriverafoxnews"
# 3     b'rt @ronnehring: third poll now showing  cruz  with 8 or 9 point solid lead over  beto  o\xe2\x80\x99  beto   (d-hollywood). follows quinnipiac and ny times\xe2\x80\xa6'
# 4     b' beto  o\xe2\x80\x99  beto  , the democratic congressman from el paso, has made the texas race for us senate one of the most widel\xe2\x80\xa6 https://t.co/f9i3qqej6u'
# 5     b'rt @wfaa: does texas\xe2\x80\x99 senate race belong to texans? https://t.co/ccbbwh5pmt https://t.co/gxnrzdjhid'
# 6     b"rt @lizlogan76:  beto  could win this, because of aca alone.  this is the winning issue, get the word out, vote for   beto   if you valu\xe2\x80\xa6"
# 7     b"rt @foxnews:   cruz  ,   beto   try to rally latino voters in the texas senate race. https://t.co/ynxbe6uvpb"
# 8     b"rt @patriot_musket: lots of really good news for house and senate republicans in this weekend's and today's polls. \n\nand lol that cook stil\xe2\x80\xa6"
# 9     b"rt @amhotflash:  beto 's campaign has raised more money in a single quarter, than any senate race in the history of this country. # beto  is ma\xe2\x80\xa6"
# 10    b"rt @johncornyn:  cruz  vs.   beto   is most expensive u.s. senate race in history https://t.co/qugxt4osl5"
# 11    b'rt @msnbc: "  cruz   has insis  cruz   that we repeal every single word of the affordable care act, including protections for pre-existing condi\xe2\x80\xa6'
# 12    b"rt @foxnews:   cruz  ,   beto   try to rally latino voters in the texas senate race. https://t.co/ynxbe6uvpb"
# 13    b"  cruz  ,   beto   try to rally latino voters in texas senate race\n\nhttps://t.co/xltuanagns"
# 14    b'rt @msnbc: "  cruz   has insis  cruz   that we repeal every single word of the affordable care act, including protections for pre-existing condi\xe2\x80\xa6'
# 15    b'rt @unitebluetx:   cruz   declines, so challenger  beto  o\xe2\x80\x99  beto   gets an hour on national tv by himself https://t.co/xs69iplqw2 #resist #bet\xe2\x80\xa6'
# 16    b"rt @foxnews:   cruz  ,   beto   try to rally latino voters in the texas senate race. https://t.co/ynxbe6uvpb"
# 17    b"rt @johncornyn:  cruz  vs.   beto   is most expensive u.s. senate race in history https://t.co/qugxt4osl5"
# 18    b'@seanastin what are your thoughts on  beto  in the texas senate race? curious'
# 19    b'.# beto forsenate\n# beto fortexas \n\xe2\x9a\xa1\xef\xb8\x8f \xe2\x80\x9cnew york times profiles evangelical christians ahead of texas senate race\xe2\x80\x9d https://t.co/hnf6wid5uq'
# 20    b'does texas\xe2\x80\x99 senate race belong to texans? - dallas business journal \xe2\x80\x9c...the occupation most represen  cruz   by  cruz \xe2\x80\x99s o\xe2\x80\xa6 https://t.co/gpfn2dt7vd'
# 21    b"rt @amhotflash:  beto 's campaign has raised more money in a single quarter, than any senate race in the history of this country. # beto  is ma\xe2\x80\xa6"
# 22    b"does texas' senate race belong to texans? https://t.co/gqynixw9yh"
# 23    b'rt @dtxergaomnes: new poll has  beto  o\xe2\x80\x99  beto   beating   cruz   by two points.\n\nif you want those poll results, get out the early vote for be\xe2\x80\xa6'
# 24    b"rt @amhotflash:  beto 's campaign has raised more money in a single quarter, than any senate race in the history of this country. # beto  is ma\xe2\x80\xa6"
# 25    b'rt   beto  : \xe2\x80\x9ci was initially intrigued by his campaign strategy. hearing someone say they aren\xe2\x80\x99t going to take any money from pacs cau\xe2\x80\xa6'
# 26    b'more voter purges in heavily contes  cruz   senate race - this time it\xe2\x80\x99s texas https://t.co/jsfd4bxsyu'
# 27    b"rt @foxnews:   cruz  ,   beto   try to rally latino voters in the texas senate race. https://t.co/ynxbe6uvpb"
# 28    b'rt @msnbc: "  cruz   has insis  cruz   that we repeal every single word of the affordable care act, including protections for pre-existing condi\xe2\x80\xa6'
# 29    b"  cruz  ,   beto   try to rally latino voters in texas senate race ~ https://t.co/xn85hvenk4 https://t.co/uzthpo9hzk"
# ...                                                                                                                       ...
# 5711  b'rt @rjc: \xe2\x80\x9ci want to cut your taxes; congressman o\xe2\x80\x99  beto   wants to raise your taxes,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5712  b'rt @rjc: \xe2\x80\x9ci want to cut your taxes; congressman o\xe2\x80\x99  beto   wants to raise your taxes,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5713  b'rt @cbsnews: "don\'t interrupt me, jason," says   cruz   as the moderator tried to ask a follow-up question on the importance of remaining c\xe2\x80\xa6'
# 5714  b'rt @outfrontcnn: in texas, can the democratic "nice guy" take off the gloves and go on the attack against the republican incumbent?  \n\n@bet\xe2\x80\xa6'
# 5715  b'rt @cbsnews: "don\'t interrupt me, jason," says   cruz   as the moderator tried to ask a follow-up question on the importance of remaining c\xe2\x80\xa6'
# 5716  b"rt @maccarty62: @gkeile @childlikefaaith yes,,,money can't and won't buy our votes!! texas for  cruz !! we need to keep at it and make sure c\xe2\x80\xa6"
# 5717  b'rt @truthsoldierz: 20 days to vote!!\n  #elpaso #texas \n\ntuesday\nnovember 6, 2018\n\n\xf0\x9f\x94\xbakeep america great\xf0\x9f\x94\xba\n\xf0\x9f\x94\xbavote republican\xf0\x9f\x94\xba\n\nvote rick seeberg\xe2\x80\xa6'
# 5718  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5719  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5720  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5721  b"rt @hadleybeetee: @teapainusa   beto   let's get him to the senate first, though. come on, texas!"
# 5722  b'rt @cbsnews:  cruz  criticizes o\'  beto   for supporting mr. trump\'s impeachment, calling it a "partisan circus."\n\n"really interesting to hear\xe2\x80\xa6'
# 5723  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5724  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5725  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5726  b"battle of the rodents in texas senate race:  beto 's blind squirrel vs.  cruz 's missing hamster | 2018 elections | dal\xe2\x80\xa6 https://t.co/d68s0qbecs"
# 5727  b'i can name off towns and cities in texas too. does that mean i can run for senate like francis.\n\n#texasdebate\xe2\x80\xa6 https://t.co/qh4rp5arlt'
# 5728  b'rt @salon:  beto  o\xe2\x80\x99  beto   dominates   cruz   in texas senate debate https://t.co/zjnuph5cpw'
# 5729  b'rt @cbsnews: "don\'t interrupt me, jason," says   cruz   as the moderator tried to ask a follow-up question on the importance of remaining c\xe2\x80\xa6'
# 5730  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5731  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5732  b'rt @matthewamiller: the texas senate race is about a lot of things, but one of them is the choice between a normal human being and an andro\xe2\x80\xa6'
# 5733  b'rt @ny2bos73: texas has a chance to do something really special. they have a chance to give this unbelievable man, who is as smart and cari\xe2\x80\xa6'
# 5734  b"  beto   attacks  cruz  with 'lyin'   cruz  ' nickname in testy debate - abc news https://t.co/qcjwo7xkih (via @abc)"
# 5735  b'rt @cbsnews: "don\'t interrupt me, jason," says   cruz   as the moderator tried to ask a follow-up question on the importance of remaining c\xe2\x80\xa6'
# 5736  b'rt @abcpolitics: rep.  beto  o\'  beto   attacks sen.   cruz  , reviving the "lyin\'   cruz  " nickname, in a testy texas senate debate https://t.co/y\xe2\x80\xa6'
# 5737  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5738  b"rt @jennycohn1: 11/ looking ahead to   beto  's texas senate race against   cruz  , we have a serious election integrity problem becaus\xe2\x80\xa6"
# 5739  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
# 5740  b'rt @kwilli1046: whom do you believe will win the texas senate race?\n\nplease vote and retweet for bigger sample size'
#
# [5741 rows x 2 columns]

# %%
# Let's write a function to take care of the ISSUES
def replace_issues(text):
    
    text = text.lower()
    
    healthcare = ['affordable care act' , "healthcare", "aca"]
    taxes = ['tax', 'taxes']
    climatechange = ['climate', 'climatechange']
    bordercontrol = ['border', 'immigration', 'bordersecurity', 'borders']
    character = ['lyin', 'leader']
    
    for w in healthcare:
        try:
            text = text.replace(w, ' healthcare ')
        except:
            pass
    for w in taxes:
        try:
            text = text.replace(w, ' taxes ')
        except:
            pass
    for w in climatechange:
        try:
            text = text.replace(w, ' climatechange ')
        except:
            pass
    for w in bordercontrol:
        try:
            text = text.replace(w, ' bordercontrol ')
        except:
            pass

    for w in character:
        try:
            text = text.replace(w, ' character ')
        except:
            pass
    
    return text

# %%
# apply replace_issues() on each tweet
text_column = []
for t in tweets.itertuples():
    text = t.text
    new_text = replace_issues(text)
    text_column.append(new_text)

# %%
# replace old text with new text
tweets.text = text_column

# %%
tweets[tweets['text'].str.contains("taxes")]
# Out:
#                      location  \
# 3118  New York, USA
# 3154  Tyler,Texas
# 3189  St Louis, MO
# 3253  Republic of Texas
# 3287  Arizona, USA
# 3292  Texas
# 3366  San Antonio, TX
# 3493  Richmond, VA
# 3496  San Antonio, TX
# 3561  Texas
# 3595  Texas
# 3639  Washington, DC
# 3672  NaN
# 3679  Ca, Co, NY, Fl, Ak, USA
# 3691  West Virginia, USA
# 3775  NaN
# 3898  NaN
# 3912  Colorado, USA
# 3918  NaN
# 3926  NaN
# 3950  NaN
# 3974  Bedminster, NJ
# 3993  Texas U S A
# 4034  Queens, NY
# 4045  Chicagoland
# 4049  Florida
# 4062  NaN
# 4066  NaN
# 4069  NaN
# 4070  U.S.
# ...    ...
# 5194  East Tennessee
# 5203  Texas 🤘 Yellowstone
# 5210  NaN
# 5222  Arizona, USA
# 5233  California, USA
# 5234  NaN
# 5241  NaN
# 5269  NaN
# 5318  Northwest USA
# 5319  NaN
# 5324  United States
# 5335  Wainwright, Alberta
# 5342  wichita, ks
# 5344  Florida, USA
# 5383  Michigan, USA
# 5389  Colorado, USA
# 5405  NaN
# 5418  Lebanon, TN
# 5465  NaN
# 5481  Texas, USA
# 5497  🇺🇸
# 5520  NaN
# 5536  Texas, USA
# 5563  United States
# 5618  NaN
# 5630  NaN
# 5644  Las Vegas, NV
# 5709  Indiana, USA
# 5711  NaN
# 5712  NaN
#
#                                                                                                                                                                                                                        text
# 3118  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3154  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3189  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 3253  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3287  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3292  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3366  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3493  b"rt @apcentralregion: an #apfactcheck on the   cruz   and   beto   senate debate in texas examines claims on oil   taxes  es, impeachment and\xe2\x80\xa6"
# 3496  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3561  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3595  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3639  b'  beto   yes! vote  beto ! we need more socialists &amp; open  bordercontrol s in texas! we need his assistance in raising   taxes  \xe2\x80\xa6 https://t.co/h0lwhoqm3h'
# 3672  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3679  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 3691  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3775  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3898  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3912  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3918  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3926  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3950  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3974  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 3993  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 4034  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 4045  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 4049  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 4062  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 4066  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 4069  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 4070  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# ...                                                                                                                                                                                                                     ...
# 5194  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5203  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5210  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5222  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5233  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5234  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5241  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5269  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 5318  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 5319  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 5324  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 5335  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5342  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5344  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5383  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5389  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 5405  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5418  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5465  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5481  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5497  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5520  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5536  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5563  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5618  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 5630  b'rt @charlesppierce: i watched the texas senate debate tonight. i wish republicans would stop using the "jfk ran on   taxes   cuts" dodge to excus\xe2\x80\xa6'
# 5644  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5709  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5711  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
# 5712  b'rt @rjc: \xe2\x80\x9ci want to cut your   taxes  es; congressman o\xe2\x80\x99  beto   wants to raise your   taxes  es,\xe2\x80\x9d mr.  cruz  said in his closing remarks. \xe2\x80\x9ci want to keep\xe2\x80\xa6'
#
# [115 rows x 2 columns]

# %%
# do another word count
# put all tweets together
text=tweets["text"].values.tolist()
text=" ".join(text)
text = text.lower()

# tokenize the text 
tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(text)

# counter object
words = Counter()

# update counter with new words
words.update(tokens)

# %%
# issues
issues = ['healthcare', 'taxes', 'climatechange', 'bordercontrol', 'character']

# %%
# lets do this again: remove stop words, single letter variable names
filter_words = Counter(x for x in tokens if x not in stopwords and x.isdigit() == False and len(x) != 1 and x.isalpha() == True and x in issues)

# %%
filter_words.most_common()[:]
# Out:
# [('healthcare', 730),
#  ('character', 289),
#  ('taxes', 196),
#  ('bordercontrol', 64),
#  ('climatechange', 36)]

# %% [markdown]
# Issues:
# * healthcare
# * character
# * taxes
# * bordercontrol

# %% [markdown]
# #### Calculate Lift for Candidate / Issue

# %% [markdown]
# Get count of tweets mentioning Beto / Cruz, and count of all tweets with Beto and/or Cruz in it

# %%
beto_count = 0
cruz_count = 0
n_tweets = 0
for t in tweets.itertuples():
    if 'beto' in t.text and 'cruz' in t.text:
        beto_count += 1
        cruz_count += 1
        n_tweets += 1
    elif 'beto' in t.text:
        beto_count += 1
        n_tweets += 1
    elif 'cruz' in t.text:
        cruz_count += 1        
        n_tweets += 1

# %% [markdown]
# Get count of tweets for each issue!

# %%
healthcare_count = 0
character_count = 0
taxes_count = 0
bordercontrol_count = 0
for t in tweets.itertuples():
    if 'healthcare' in t.text:
        healthcare_count += 1
    elif 'character' in t.text:
        character_count += 1
    elif 'taxes' in t.text:
        taxes_count += 1
    elif 'bordercontrol' in t.text:
        bordercontrol_count += 1

# %% [markdown]
# Get count of tweets with
#
# Beto/healthcare, Beto/character, Beto/taxes, Beto/bordercontrol
#
#
# Cruz/healthcare, Cruz/character, Cruz/taxes, Cruz/bordercontrol

# %%
# beto and issues
bh_count = 0
bc_count = 0
bt_count = 0
bb_count = 0

# cruz and issues
ch_count = 0
cc_count = 0
ct_count = 0
cb_count = 0

for t in tweets.itertuples():
    # beto
    if 'beto' in t.text and 'healthcare' in t.text:
        bh_count += 1
    if 'beto' in t.text and 'character' in t.text:
        bc_count += 1
    if 'beto' in t.text and 'taxes' in t.text:
        bt_count += 1
    if 'beto' in t.text and 'bordercontrol' in t.text:
        bb_count += 1
    
    # cruz
    if 'cruz' in t.text and 'healthcare' in t.text:
        ch_count += 1
    if 'cruz' in t.text and 'character' in t.text:
        cc_count += 1
    if 'cruz' in t.text and 'taxes' in t.text:
        ct_count += 1
    if 'cruz' in t.text and 'bordercontrol' in t.text:
        cb_count += 1

# %%
candidate_counts = [beto_count, cruz_count]
issue_counts = [healthcare_count, character_count, taxes_count, bordercontrol_count]
combo_counts = [bh_count, bc_count, bt_count, bb_count, ch_count, cc_count, ct_count, cb_count]
lifts = [] # order: [0] beto vs healthcare, [1] beto vs character, [2] beto vs taxes, [3] beto vs bordercontrol
           #        [4] cruz vs healthcare, [5] cruz vs character, [6] cruz vs taxes, [7] cruz vs bordercontrol
index = 0
for cand_count in candidate_counts:
    for issue_count in issue_counts:
        lifts.append( (len(tweets) * combo_counts[index]) / (cand_count * issue_count) )
        index +=1 
lifts_copy = lifts[:]

# %%
lifts = np.reshape(lifts, (2, 4)).T # reshape for similarities matrix

# %%
similarities = pd.DataFrame(lifts, columns=['beto', 'cruz'], index=['healthcare', 'character', 'taxes', 'bordercontrol'])

# %%
similarities
# Out:
#                    beto      cruz
# healthcare     0.171859  1.546513
# character      1.674005  0.524548
# taxes          1.275317  1.225257
# bordercontrol  0.412301  1.088287

# %% [markdown]
# ## Sentiment Analysis

# %%
# ask if key word in the string
# split into list
# identify the index of the key word
# get list of +/- 3 indexes from key word
# concated list back to string
# return string
def get_substring(key_word, s):
    """
        1. ask if key word in the string
        2. split into list
        3. identify the index of the key word
        4. get list of +/- radius indexes from key word
        5. concated list back to string
        6. return string
    """

    # get rid of "b'" at beginning of tweet
    s = s[2:]

    # get rid of rt stuff if there
    if 'rt @' in s:
        end_of_rt = s.index(':')+2
        s = s[end_of_rt:]

    s_list = s.split()

    radius = 8 # set the radius

    # using this ugly mess to try to get beto or cruz if they are next to commas or exclamation
    try:
        kw_index = s_list.index(key_word)
    except:
        try:
            kw_index = s_list.index(key_word+',')
        except:
            try:
                kw_index = s_list.index(key_word+'!')
            except:
                try:
                    kw_index = s_list.index(key_word+'.')
                except:
                    return

    # get up until key word
    sub_s_beg = []
    if radius > kw_index:
        sub_s_beg = s_list[:kw_index]
    else:
        sub_s_beg = s_list[kw_index-radius:kw_index]

    # get key word and after
    len_kw_index_to_end = len(s_list[kw_index+1:])
    sub_s_end = []
    if radius < len_kw_index_to_end:
        sub_s_end = s_list[kw_index:kw_index+radius+1]
    else:
        sub_s_end = s_list[kw_index:]

    sub_s = (' ').join(sub_s_beg + sub_s_end)
    return sub_s

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# sentiment analyzer object
analyser = SentimentIntensityAnalyzer()

# %%
# lyft values > 1
ch_sent = []
ct_sent = []
cb_sent = []
bc_sent = []
bt_sent = []

for t in tweets.itertuples():
    
    # Beto and taxes
    if 'beto' in t.text and 'taxes' in t.text:
        sub_text = get_substring('beto', t.text)
        if sub_text:
            snt = analyser.polarity_scores(sub_text)
            bt_sent.append(snt['compound'])
        
    # Beto and character
    if 'beto' in t.text and 'character' in t.text:
        sub_text = get_substring('beto', t.text)
        
        if sub_text:
            snt = analyser.polarity_scores(sub_text)
            bc_sent.append(snt['compound'])

    # cruz and taxes
    if 'cruz' in t.text and 'taxes' in t.text:
        sub_text = get_substring('cruz', t.text)
        print(sub_text)
        if sub_text:
            snt = analyser.polarity_scores(sub_text)
            print(snt['compound'])
            ct_sent.append(snt['compound'])
            
    # cruz and bordercontrol
    if 'cruz' in t.text and 'bordercontrol' in t.text:
        sub_text = get_substring('cruz', t.text)
        if sub_text:
            snt = analyser.polarity_scores(sub_text)
            cb_sent.append(snt['compound'])

    # cruz and healthcare
    if 'cruz' in t.text and 'healthcare' in t.text:
        sub_text = get_substring('cruz', t.text)
        if sub_text:
            snt = analyser.polarity_scores(sub_text)
            ch_sent.append(snt['compound'])
# Out:
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# an #apfactcheck on the cruz and beto senate debate in texas examines claims
# 0.0
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772
# beto wants to raise your taxes es,\xe2\x80\x9d mr. cruz said in his closing remarks. \xe2\x80\x9ci want to
# 0.0772

# %%
# get average of list
def avg(lst): 
    return sum(lst) / len(lst)

# %%
# order [0] beto/big [1] cruz/big [2] beto/small [3] cruz/small
sentiments = [avg(ch_sent), avg(ct_sent), avg(cb_sent), avg(bc_sent), avg(bt_sent)]

# %%
sentiments
# Out:
# [0.0020593607305936074,
#  0.07625853658536597,
#  0.799931578947369,
#  0.5177222222222215,
#  -0.19130481927710813]

# %%
final_table = pd.DataFrame(None, columns=['lift', 'sentiment score'], index=['healthcare & beto', 'character& beto', 'taxes & beto', 'bordercontrol & beto',
                                                                             'healthcare & cruz','character& cruz','taxes & cruz','bordercontrol & cruz'])

# %%
final_table['lift']=lifts_copy

# %%
final_table
# Out:
#                           lift sentiment score
# healthcare & beto     0.171859  NaN
# character& beto       1.674005  NaN
# taxes & beto          1.275317  NaN
# bordercontrol & beto  0.412301  NaN
# healthcare & cruz     1.546513  NaN
# character& cruz       0.524548  NaN
# taxes & cruz          1.225257  NaN
# bordercontrol & cruz  1.088287  NaN

# %%
final_table['sentiment score']['healthcare & cruz']= sentiments[0]
final_table['sentiment score']['taxes & cruz']= sentiments[1]
final_table['sentiment score']['bordercontrol & cruz']= sentiments[2]
final_table['sentiment score']['character& beto']= sentiments[3]
final_table['sentiment score']['taxes & beto']= sentiments[4]
# Out:
# c:\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# c:\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\python\python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# c:\python\python37\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
final_table
# Out:
#                           lift sentiment score
# healthcare & beto     0.171859  NaN
# character& beto       1.674005  0.517722
# taxes & beto          1.275317 -0.191305
# bordercontrol & beto  0.412301  NaN
# healthcare & cruz     1.546513  0.00205936
# character& cruz       0.524548  NaN
# taxes & cruz          1.225257  0.0762585
# bordercontrol & cruz  1.088287  0.799932

# %% [markdown]
# The lift between taxes and beto is at 1.275317 and the sentiment score is -0.191305. Beto should focus addressing why he supports tax increases and illustrate the pros of such policy to address the current negative sentiment.
#
# The lift between character and beto is at 1.674005 and the sentiment score is 0.517722. Beto should continue to demonstate his image as a candidate with high integrity. One distinctive feature seen in the tweets concerning his character involve words such as "leader" and "proud to support".
#
# The lift between bordercontrol and cruz is at 1.088287 and the sentiment score is 0.799932. Cruz should continue to strongly support his strict policies on immigration.
#
# The lift between healthcare and cruz is at 1.546513 and the sentiment score is 0.00205936. Although there is a clear association between cruz and healthcare the sentiment score is neutral and so cruz has an opportunity to leverage this buzz and gain more supporters. Our data tells us that people are aware of healthcare as an issue, knowing that the candidates can use this as a talking point in each of their favor.
#
# The lift between taxes and cruz is at 1.225257 and the sentiment score is 0.0762585. Cruz should continue to emphasize his support for lower taxes. This should be a core differentiator for Cruz as Beto has a negative sentiment on the same issue with a lift value.
